# %%
pip install pyvis
# Out:
# Requirement already satisfied: pyvis in /opt/anaconda3/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: jinja2>=2.9.6 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (2.11.3)
# Requirement already satisfied: networkx>=1.11 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (2.6.3)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (7.29.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (2.1.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (58.0.4)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.18.0)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.1.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (2.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9.6->pyvis) (1.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import packages. Run this cell.
import numpy as np
import numpy.random as rn
from numpy.core.fromnumeric import shape
from pyvis import network as net
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque
import torch.optim as optim
from matplotlib import pyplot as plt

# %%
"""
Define the environment
"""

class Gridworld(object):
    """
    Topology MDP.
    """

    def __init__(self, reward_list, discount = 0.95):
        """
        Topology G(9, 16)
        """
        g = net.Network(height='400px', width='50%', heading='')
        self.reward_list = reward_list # Reward list
        self.n_states = 9 # number of states
        # Build the network
        for i in range(self.n_states):
            g.add_node(i)
        g.add_edge(0,1)
        g.add_edge(1,2)
        g.add_edge(2,3)
        g.add_edge(3,0)
        g.add_edge(4,5)
        g.add_edge(5,6)
        g.add_edge(6,7)
        g.add_edge(7,8)
        g.add_edge(4,7)
        g.add_edge(0,4)
        g.add_edge(1,5)
        g.add_edge(2,6)
        g.add_edge(3,7)
        g.add_edge(4,8)
        g.add_edge(5,8)
        g.add_edge(6,8)
        g.add_edge(7,8)
        self.n_arcs = len(g.edges) # num of arcs 16
        self.arcs = g.edges
        self.neighbor_map = g.get_adj_list()
        self.from_set = []
        self.to_set = []
        for j in range(self.n_arcs):
            self.from_set.append(g.edges[j]['from'])
        for j in range(self.n_arcs):
            self.to_set.append(g.edges[j]['to'])
        self.from_set = np.array(self.from_set)
        self.to_set = np.array(self.to_set)
        self.discount = discount

    def state_transition_func(self, state, action):
        """
        Map (current pos and next pos) to the arc
        """
        if np.random.random() <= 0.9:
            next = list(self.neighbor_map[state])[action]
        else:
            a = np.random.randint(len(list(self.neighbor_map[state])))
            next = list(self.neighbor_map[state])[a]
        return next

    def reset(max_num):
        """
        New aircraft comes in
        """
        state = np.random.randint(0,max_num,[9,9])
        np.fill_diagonal(state, 0)
        return state

    def canonical_arc(self, cur, next):
        """
        With current and next steps, find the corresponding arc
        """
        # if cur in the from set
        arc_idx = -1
        
        if next in self.from_set[np.where(self.to_set==cur)]:
            arc_idx = np.intersect1d(np.where(self.to_set==cur), np.where(self.from_set==next))
        else:
            arc_idx = np.intersect1d(np.where(self.to_set==next), np.where(self.from_set==cur))
            
        # if self.from_set[self.to_set.index(cur)] == next:
        #     arc_idx = self.to_set.index(cur)
        #     print(arc_idx)
        # elif self.to_set[self.from_set.index(cur)] == next:
        #     arc_idx = self.from_set.index(cur)
        # else:
        #     arc_idx = self.from_set.index(cur)        
        return arc_idx.squeeze()     

    def step(self, state, action, terminal_state):
        arc_idx = 0
        next_state = self.state_transition_func(state, action)
        arc_idx = self.canonical_arc(state, next_state)     
        reward = self.reward_list[arc_idx]
        if state == terminal_state:
            done = True
        else:
            done = False
        return next_state, reward, done


    def value_iteration(self, des):
        """
        Please use value iteration to compute the optimal value function and store it into the vector V with size 64
        For example, V[0] means the optimal value function for state 0.
        """
        V = np.zeros((9,))
        V_old = np.zeros((9,))
        flag = 1
        while flag:
          for state in range(9):
            if(state == des):
              V[state] = 0
              continue
            list = []

            if state ==0 or state == 1 or state == 2 or state ==3:
                  for action in range(3):  
                    next_state, reward, done = self.step(state, action, terminal_state = des)
                    list.append(self.discount * V_old[next_state] + (reward-1))
                  V[state] = max(list) 
            else:

                  for action in range(4):
                    next_state, reward, done = self.step(state, action, terminal_state = des)
                    list.append(self.discount * V_old[next_state] + (reward-1))
                  V[state] = max(list) 

          # print(V)
          V_change = np.subtract(V, V_old)
          # print(V_old)
          V_change = abs(V_change)
          if np.max(V_change) < 0.1:
            flag = 0

          V_old = np.copy(V)
        return V
    
    def value_itr(self):
        V = np.zeros([9,9])
        for i in range(9):
            V[i] = np.array(self.value_iteration(i))
        return V


    def evaluate(self, agent, v):
      evaluate = np.zeros((16,))
      #print('agent',agent,v)
      for a in agent:
        value = v[int(a[1])]
        list = []
        if a[0] == 0 or a[0] == 1 or a[0] == 2 or a[0] == 3 :
            max = -np.inf
            for action in range(3):
              next_state = self.state_transition_func(a[0], action)
              if value[next_state] > max:
                max = value[next_state]
                next_state_0 = next_state
            evaluate[self.canonical_arc(a[0], next_state_0)] += 1
            a[0] = next_state_0
        else:
            max = -np.inf
            for action in range(4):
              next_state = self.state_transition_func(a[0], action)
              if value[next_state] > max:
                next_state_0 = next_state
            evaluate[self.canonical_arc(a[0], next_state)] += 1
            a[0] = next_state_0
      return evaluate,agent

    def score_fun(self,evaluate):
      score = 0
      score = -0.1 * np.sum((self.reward_list) * evaluate) - np.sum(np.maximum(evaluate - np.ones(16),np.zeros(16)))
      return score

    def from_agent_to_config(self,agent):
      config = np.zeros([9,9])
      for a in agent:
        config[a[1],a[0]] += 1
        config = self.clean_config(config)
      return config

    def from_config_to_agent(self,config):
      agent = []
      config = self.clean_config(config)
      config = config.reshape([9,9])
      for i in range(9):
        for j in range(9):
          while config[i,j] != 0:
            agent.append([j,i])
            config[i,j] -= 1
      return agent
    
    def clean_config(self,config):
      if len(config.shape) == 1:
        config = config.reshape([9,9])
      np.fill_diagonal(config, 0)
      return config

    def config_step(self,config):
      V = self.value_itr()
      config = self.clean_config(config)
      agent = self.from_config_to_agent(config)
      evaluate,agent = self.evaluate(agent,V)
      next_config = self.from_agent_to_config(agent)
      next_config = self.clean_config(next_config)
      score = self.score_fun(evaluate)
      return next_config,score

    def add_random_des():
      return

# %%
"""
Some parameters
"""
state_size = 9*9  # state dimension
action_size = 16  # action dimension
fc_units = 256  # number of neurons in one fully connected hidden layer
action_upper_bound = 1  # action space upper bound
action_lower_bound = -1  # action space lower bound


"""
Structure of Actor Network.
"""
class Actor(nn.Module):
    def __init__(self):
        super().__init__()
        self.max_action = action_upper_bound
        self.fc1 = nn.Linear(state_size, fc_units)
        self.fc2 = nn.Linear(fc_units, fc_units)
        self.fc3 = nn.Linear(fc_units, action_size)

    def forward(self, state):
        """
        Build an actor (policy) network that maps states -> actions.
        Args:
            state: torch.Tensor with shape (batch_size, state_size)
        Returns:
            action: torch.Tensor with shape (batch_size, action_size)
        """
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        action = torch.tanh(self.fc3(x)) * self.max_action
        return action


"""
Structure of Critic Network.
"""
class CriticQ(nn.Module):
    def __init__(self):
        """
        Args:
            state_size: state dimension
            action_size: action dimension
            fc_units: number of neurons in one fully connected hidden layer
        """
        super().__init__()
        
        # Q-network 1 architecture
        self.l1 = nn.Linear(state_size + action_size, fc_units)
        self.l2 = nn.Linear(fc_units, fc_units)
        self.l3 = nn.Linear(fc_units, 1)

        # Q-network 2 architecture
        self.l4 = nn.Linear(state_size + action_size, fc_units)
        self.l5 = nn.Linear(fc_units, fc_units)
        self.l6 = nn.Linear(fc_units, 1)

    def forward(self, state, action):
        """
        Build a critic (value) network that maps state-action pairs -> Q-values.
        Args:
            state: torch.Tensor with shape (batch_size, state_size)
            action: torch.Tensor with shape (batch_size, action_size)
        Returns:
            Q_value_1: torch.Tensor with shape (batch_size, 1)
            Q_value_2: torch.Tensor with shape (batch_size, 1)
        """
        state_action = torch.cat([state, action], 1)
        
        x1 = F.relu(self.l1(state_action))
        x1 = F.relu(self.l2(x1))
        Q_value_1 = self.l3(x1)
        
        x2 = F.relu(self.l4(state_action))
        x2 = F.relu(self.l5(x2))
        Q_value_2 = self.l6(x2)
        
        return Q_value_1, Q_value_2

# %%
"""
Implementation of TD3 Algorithm
"""
import random
class TD3:
    def __init__(self):
        self.lr_actor = 1e-2  # learning rate for actor network
        self.lr_critic = 1e-2  # learning rate for critic network
        self.buffer_capacity = 100000  # replay buffer capacity
        self.batch_size = 128  # mini-batch size
        self.tau = 0.02  # soft update parameter
        self.policy_delay = 2  # policy will be updated once every policy_delay times for each update of the Q-networks.
        self.gamma = 0.99  # discount factor
        self.target_noise = 0.2  # standard deviation for smoothing noise added to target policy
        self.noise_clip = 0.5  # limit for absolute value of target policy smoothing noise.
        self.update_every = 200  # number of env interactions that should elapse between updates of Q-networks.
        # Note: Regardless of how long you wait between updates, the ratio of env steps to gradient steps should be 1.
        self.state_size = state_size
        self.action_size = action_size
        self.device = torch.device("cpu")  # or self.device = torch.device("cuda")
        self.action_upper_bound = action_upper_bound  # action space upper bound
        self.action_lower_bound = action_lower_bound  # action space lower bound
        self.create_actor()
        self.create_critic()
        self.act_opt = optim.Adam(self.actor.parameters(), lr=self.lr_actor)
        self.crt_opt = optim.Adam(self.critic.parameters(), lr=self.lr_critic)
        self.replay_memory_buffer = deque(maxlen=self.buffer_capacity)
        
    def create_actor(self):
        self.actor = Actor().to(self.device)
        self.actor_target = Actor().to(self.device)
        self.actor_target.load_state_dict(self.actor.state_dict())

    def create_critic(self):
        self.critic = CriticQ().to(self.device)
        self.critic_target = CriticQ().to(self.device)
        self.critic_target.load_state_dict(self.critic.state_dict())
    
    def add_to_replay_memory(self, state, action, reward, next_state, done):
        """
        Add samples to replay memory
        Args:
            state: current state, a numpy array with shape (state_size,)
            action: current action, a numpy array with shape (action_size,)
            reward: reward obtained
            next_state: next state, a numpy array with shape (state_size,)
            done: True when the current episode ends, False otherwise
        """
        self.replay_memory_buffer.append((state, action, reward, next_state, done))

    def get_random_sample_from_replay_mem(self):
        """
        Random samples from replay memory without replacement
        Returns a self.batch_size length list of unique elements chosen from the replay buffer.
        Returns:
            random_sample: a list with len=self.batch_size,
                           where each element is a tuple (state, action, reward, next_state, done)
        """
        random_sample = random.sample(self.replay_memory_buffer, self.batch_size)
        return random_sample
    
    def soft_update_target(self, local_model, target_model):
        """
        Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Args:
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(self.tau*local_param.data + (1.0-self.tau)*target_param.data)

    def train(self, cur_time_step, episode_time_step, state, action, reward, next_state, done):
        """
        Collect samples and update actor network and critic network using mini-batches of experience tuples.
        Args:
            cur_time_step: current time step counting from the beginning, 
                           which is equal to the number of times the agent interacts with the environment
            episode_time_step: the time step counting from the current episode
            state: current state, a numpy array with shape (state_size,)
            action: current action, a numpy array with shape (action_size,)
            reward: reward obtained
            next_state: next state, a numpy array with shape (state_size,)
            done: True when the current episode ends, False otherwise
        """
        self.add_to_replay_memory(state, action, reward, next_state, done)      
        if len(self.replay_memory_buffer) < self.batch_size:
            return
        if cur_time_step % self.update_every != 0:
            return
        
        # Perform self.update_every times of updates of the critic networks and 
        # (self.update_every / policy_delay) times of updates of the actor network
        for it in range(self.update_every): 
            """
            state_batch: torch.Tensor with shape (self.batch_size, state_size), a mini-batch of current states
            action_batch: torch.Tensor with shape (self.batch_size, action_size), a mini-batch of current actions
            reward_batch: torch.Tensor with shape (self.batch_size, 1), a mini-batch of rewards
            next_state_batch: torch.Tensor with shape (self.batch_size, state_size), a mini-batch of next states
            done_list: torch.Tensor with shape (self.batch_size, 1), a mini-batch of 0-1 integers, 
                   where 1 means the episode terminates for that sample;
                         0 means the episode does not terminate for that sample.
            """
            mini_batch = self.get_random_sample_from_replay_mem()
            state_batch = torch.from_numpy(np.vstack([i[0] for i in mini_batch])).float().to(self.device)
            action_batch = torch.from_numpy(np.vstack([i[1] for i in mini_batch])).float().to(self.device)
            reward_batch = torch.from_numpy(np.vstack([i[2] for i in mini_batch])).float().to(self.device)
            next_state_batch = torch.from_numpy(np.vstack([i[3] for i in mini_batch])).float().to(self.device)
            done_list = torch.from_numpy(np.vstack([i[4] for i in mini_batch]).astype(np.uint8)).float().to(self.device)
            
            # Please complete codes for updating the critic networks
            """
            Hints: 
              You may use the above tensors: state_batch, action_batch, reward_batch, next_state_batch, done_list
              You may use self.critic_target and self.actor_target as your target networks
              you may use target policy smoothing techniques with hyperparameters self.target_noise and self.noise_clip
              You may use clipped double Q-learning techniques
              You may update self.critic using the optimizer self.crt_opt and MSE loss function.
              Make sure to consider whether the corresponding episode terminates when calculating target values.
                If the episode terminates, then the next state value should be 0.
            """
            ### BEGIN SOLUTION
            # YOUR CODE HERE
            current_q = self.critic(state_batch,action_batch)
            next_action_batch = self.actor_target(next_state_batch) + torch.clamp(torch.normal(0,0.2,action_batch.shape),-self.noise_clip,self.noise_clip)
            target_q1 = reward_batch + torch.mul(torch.mul(self.critic_target(next_state_batch,next_action_batch)[0].detach(),self.gamma),1-done_list)
            target_q2 = reward_batch + torch.mul(torch.mul(self.critic_target(next_state_batch,next_action_batch)[1].detach(),self.gamma),1-done_list)
            
            y = torch.min(target_q1,target_q2)
            loss = ((torch.sum((y - current_q[0])**2) + torch.sum((y - current_q[1])**2))).mean()
            self.crt_opt.zero_grad()
            loss.backward()
            self.crt_opt.step()
            ### END SOLUTION
           
            # Train Actor
            # Delayed policy updates
            # Update self.actor once every policy_delay times for each update of self.critic
            if it % self.policy_delay == 0:
                
                # Please complete codes for updating of the actor network
                """
                Hint: 
                  You may update self.actor using the optimizer self.act_opt and recall the loss function for DDPG training
                """
                ### BEGIN SOLUTION
                # YOUR CODE HERE
                actor = self.actor(state_batch)
                q1,q2 = self.critic(state_batch,actor)
                loss = -sum(q1+q2)
                self.act_opt.zero_grad()
                loss.backward()
                self.act_opt.step()
                ### END SOLUTION
                
                # Soft update target models
                self.soft_update_target(self.critic, self.critic_target)
                self.soft_update_target(self.actor, self.actor_target)
            
    
    def policy(self, state):
        """
        Select action based on the actor network.
        Args:
            state: a numpy array with shape (state_size,)
        Returns:
            actions: a numpy array with shape (action_size,)
        """
        state = torch.from_numpy(state).float().unsqueeze(0).to(self.device)
        self.actor.eval()
        with torch.no_grad():
            actions = np.squeeze(self.actor(state).cpu().data.numpy())
        self.actor.train()
        return actions

# %%
def generate_config(num_max):
        state = np.random.randint(0,num_max,[9,9])
        np.fill_diagonal(state, 0)
        return state

# %%
a = np.zeros([9,9])
a = generate_config(5)
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

timesteps_count = 0  # Counting the time steps
max_steps = 24  # Maximum time steps for one episode
ep_reward_list = []
ep_reward_list_naive = []
avg_reward = -9999
agent = TD3()

for ep in range(10000):
    config = generate_config(4)
    config = config.flatten()
    episodic_reward = 0
    timestep_for_cur_episode = 0
    episodic_reward_naive = 0
    score = []

    for st in range(max_steps):
        a = np.copy(config)
        # Select action according to policy
        action = agent.policy(config.flatten())
        env = Gridworld(action)
        # Recieve state and reward from environment.
        next_config, reward = env.config_step(config)
        next_config = next_config.flatten()
        done = 0
        episodic_reward += reward
        if next_config.any() == 0:
          done = 1
        # Send the experience to the agent and train the agent
        agent.train(timesteps_count, timestep_for_cur_episode, config, action, reward, next_config, done)
        timestep_for_cur_episode += 1
        timesteps_count += 1
        
        #comparison
        action_naive = -np.zeros(16)
        env = Gridworld(action_naive)
        next_config_naive, reward_naive = env.config_step(a)
        next_config_naive = next_config_naive.flatten()
        episodic_reward_naive += reward_naive
        
        # End this episode when `done` is True
        if done:
            break
        config = next_config

    ep_reward_list.append(episodic_reward)
    ep_reward_list_naive.append(episodic_reward_naive)
    print('Ep. {}, Ep.Timesteps {}, Episode Reward: {:.2f}'.format(ep + 1, timestep_for_cur_episode, episodic_reward), end='')
    print('Ep. {}, Ep.Timesteps {}, Episode Reward_naive: {:.2f}'.format(ep + 1, timestep_for_cur_episode, episodic_reward_naive), end='')
    
    if len(ep_reward_list) == 50:
        # Mean of last 50 episodes
        avg_reward = sum(ep_reward_list) / 50
        print(', Moving Average Reward: {:.2f}'.format(avg_reward))
    else:
        print('')
print('Average reward over 50 episodes: ', avg_reward)
plt.plot(ep_reward_list,color = 'r')
plt.plot(ep_reward_list_naive, color = 'b')
print(np.mean(ep_reward_list),np.mean(ep_reward_list_naive))
# Out:
# Ep. 1, Ep.Timesteps 24, Episode Reward: -1159.55Ep. 1, Ep.Timesteps 24, Episode Reward_naive: -1136.00
# Ep. 2, Ep.Timesteps 24, Episode Reward: -1071.72Ep. 2, Ep.Timesteps 24, Episode Reward_naive: -1045.00
# Ep. 3, Ep.Timesteps 24, Episode Reward: -940.20Ep. 3, Ep.Timesteps 24, Episode Reward_naive: -921.00
# Ep. 4, Ep.Timesteps 24, Episode Reward: -1038.74Ep. 4, Ep.Timesteps 24, Episode Reward_naive: -1020.00
# Ep. 5, Ep.Timesteps 24, Episode Reward: -1234.65Ep. 5, Ep.Timesteps 24, Episode Reward_naive: -1193.00
# Ep. 6, Ep.Timesteps 24, Episode Reward: -778.50Ep. 6, Ep.Timesteps 24, Episode Reward_naive: -763.00
# Ep. 7, Ep.Timesteps 24, Episode Reward: -974.45Ep. 7, Ep.Timesteps 24, Episode Reward_naive: -953.00
# Ep. 8, Ep.Timesteps 24, Episode Reward: -851.20Ep. 8, Ep.Timesteps 24, Episode Reward_naive: -830.00
# Ep. 9, Ep.Timesteps 24, Episode Reward: -1127.87Ep. 9, Ep.Timesteps 24, Episode Reward_naive: -1075.00
# Ep. 10, Ep.Timesteps 24, Episode Reward: -1432.01Ep. 10, Ep.Timesteps 24, Episode Reward_naive: -1314.00
# Ep. 11, Ep.Timesteps 24, Episode Reward: -1266.41Ep. 11, Ep.Timesteps 24, Episode Reward_naive: -1159.00
# Ep. 12, Ep.Timesteps 24, Episode Reward: -1478.36Ep. 12, Ep.Timesteps 24, Episode Reward_naive: -1352.00
# Ep. 13, Ep.Timesteps 24, Episode Reward: -1144.17Ep. 13, Ep.Timesteps 24, Episode Reward_naive: -1060.00
# Ep. 14, Ep.Timesteps 24, Episode Reward: -1072.28Ep. 14, Ep.Timesteps 24, Episode Reward_naive: -990.00
# Ep. 15, Ep.Timesteps 24, Episode Reward: -1142.94Ep. 15, Ep.Timesteps 24, Episode Reward_naive: -1054.00
# Ep. 16, Ep.Timesteps 24, Episode Reward: -1032.45Ep. 16, Ep.Timesteps 24, Episode Reward_naive: -959.00
# Ep. 17, Ep.Timesteps 24, Episode Reward: -1225.01Ep. 17, Ep.Timesteps 24, Episode Reward_naive: -1134.00
# Ep. 18, Ep.Timesteps 24, Episode Reward: -1273.19Ep. 18, Ep.Timesteps 24, Episode Reward_naive: -1243.00
# Ep. 19, Ep.Timesteps 24, Episode Reward: -852.43Ep. 19, Ep.Timesteps 24, Episode Reward_naive: -829.00
# Ep. 20, Ep.Timesteps 24, Episode Reward: -1035.40Ep. 20, Ep.Timesteps 24, Episode Reward_naive: -991.00
# Ep. 21, Ep.Timesteps 24, Episode Reward: -953.19Ep. 21, Ep.Timesteps 24, Episode Reward_naive: -916.00
# Ep. 22, Ep.Timesteps 24, Episode Reward: -1032.73Ep. 22, Ep.Timesteps 24, Episode Reward_naive: -993.00
# Ep. 23, Ep.Timesteps 24, Episode Reward: -1010.81Ep. 23, Ep.Timesteps 24, Episode Reward_naive: -956.00
# Ep. 24, Ep.Timesteps 24, Episode Reward: -1205.55Ep. 24, Ep.Timesteps 24, Episode Reward_naive: -1141.00
# Ep. 25, Ep.Timesteps 24, Episode Reward: -1102.35Ep. 25, Ep.Timesteps 24, Episode Reward_naive: -1059.00
# Ep. 26, Ep.Timesteps 24, Episode Reward: -927.05Ep. 26, Ep.Timesteps 24, Episode Reward_naive: -943.00
# Ep. 27, Ep.Timesteps 24, Episode Reward: -1278.20Ep. 27, Ep.Timesteps 24, Episode Reward_naive: -1311.00
# Ep. 28, Ep.Timesteps 24, Episode Reward: -853.02Ep. 28, Ep.Timesteps 24, Episode Reward_naive: -876.00
# Ep. 29, Ep.Timesteps 24, Episode Reward: -1291.39Ep. 29, Ep.Timesteps 24, Episode Reward_naive: -1338.00
# Ep. 30, Ep.Timesteps 24, Episode Reward: -1102.67Ep. 30, Ep.Timesteps 24, Episode Reward_naive: -1146.00
# Ep. 31, Ep.Timesteps 24, Episode Reward: -1251.39Ep. 31, Ep.Timesteps 24, Episode Reward_naive: -1285.00
# Ep. 32, Ep.Timesteps 24, Episode Reward: -1044.34Ep. 32, Ep.Timesteps 24, Episode Reward_naive: -1065.00
# Ep. 33, Ep.Timesteps 24, Episode Reward: -896.99Ep. 33, Ep.Timesteps 24, Episode Reward_naive: -916.00
# Ep. 34, Ep.Timesteps 24, Episode Reward: -1400.63Ep. 34, Ep.Timesteps 24, Episode Reward_naive: -1367.00
# Ep. 35, Ep.Timesteps 24, Episode Reward: -1191.41Ep. 35, Ep.Timesteps 24, Episode Reward_naive: -1144.00
# Ep. 36, Ep.Timesteps 24, Episode Reward: -1397.14Ep. 36, Ep.Timesteps 24, Episode Reward_naive: -1328.00
# Ep. 37, Ep.Timesteps 24, Episode Reward: -1500.88Ep. 37, Ep.Timesteps 24, Episode Reward_naive: -1428.00
# Ep. 38, Ep.Timesteps 24, Episode Reward: -1284.39Ep. 38, Ep.Timesteps 24, Episode Reward_naive: -1223.00
# Ep. 39, Ep.Timesteps 24, Episode Reward: -1337.29Ep. 39, Ep.Timesteps 24, Episode Reward_naive: -1294.00
# Ep. 40, Ep.Timesteps 24, Episode Reward: -1209.48Ep. 40, Ep.Timesteps 24, Episode Reward_naive: -1146.00
# Ep. 41, Ep.Timesteps 24, Episode Reward: -1255.72Ep. 41, Ep.Timesteps 24, Episode Reward_naive: -1209.00
# Ep. 42, Ep.Timesteps 24, Episode Reward: -1264.90Ep. 42, Ep.Timesteps 24, Episode Reward_naive: -1242.00
# Ep. 43, Ep.Timesteps 24, Episode Reward: -1255.12Ep. 43, Ep.Timesteps 24, Episode Reward_naive: -1328.00
# Ep. 44, Ep.Timesteps 24, Episode Reward: -778.27Ep. 44, Ep.Timesteps 24, Episode Reward_naive: -827.00
# Ep. 45, Ep.Timesteps 24, Episode Reward: -1034.61Ep. 45, Ep.Timesteps 24, Episode Reward_naive: -1106.00
# Ep. 46, Ep.Timesteps 24, Episode Reward: -1035.51Ep. 46, Ep.Timesteps 24, Episode Reward_naive: -1093.00
# Ep. 47, Ep.Timesteps 24, Episode Reward: -970.70Ep. 47, Ep.Timesteps 24, Episode Reward_naive: -1030.00
# Ep. 48, Ep.Timesteps 24, Episode Reward: -874.71Ep. 48, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 49, Ep.Timesteps 24, Episode Reward: -633.75Ep. 49, Ep.Timesteps 24, Episode Reward_naive: -682.00
# Ep. 50, Ep.Timesteps 24, Episode Reward: -1107.05Ep. 50, Ep.Timesteps 24, Episode Reward_naive: -1187.00, Moving Average Reward: -1112.25
# Ep. 51, Ep.Timesteps 24, Episode Reward: -1016.83Ep. 51, Ep.Timesteps 24, Episode Reward_naive: -1077.00
# Ep. 52, Ep.Timesteps 24, Episode Reward: -1039.61Ep. 52, Ep.Timesteps 24, Episode Reward_naive: -1074.00
# Ep. 53, Ep.Timesteps 24, Episode Reward: -1069.47Ep. 53, Ep.Timesteps 24, Episode Reward_naive: -1108.00
# Ep. 54, Ep.Timesteps 24, Episode Reward: -1104.43Ep. 54, Ep.Timesteps 24, Episode Reward_naive: -1149.00
# Ep. 55, Ep.Timesteps 24, Episode Reward: -1119.12Ep. 55, Ep.Timesteps 24, Episode Reward_naive: -1182.00
# Ep. 56, Ep.Timesteps 24, Episode Reward: -1190.09Ep. 56, Ep.Timesteps 24, Episode Reward_naive: -1243.00
# Ep. 57, Ep.Timesteps 24, Episode Reward: -1224.15Ep. 57, Ep.Timesteps 24, Episode Reward_naive: -1275.00
# Ep. 58, Ep.Timesteps 24, Episode Reward: -1016.80Ep. 58, Ep.Timesteps 24, Episode Reward_naive: -1081.00
# Ep. 59, Ep.Timesteps 24, Episode Reward: -898.52Ep. 59, Ep.Timesteps 24, Episode Reward_naive: -914.00
# Ep. 60, Ep.Timesteps 24, Episode Reward: -1079.90Ep. 60, Ep.Timesteps 24, Episode Reward_naive: -1073.00
# Ep. 61, Ep.Timesteps 24, Episode Reward: -1393.82Ep. 61, Ep.Timesteps 24, Episode Reward_naive: -1389.00
# Ep. 62, Ep.Timesteps 24, Episode Reward: -1279.60Ep. 62, Ep.Timesteps 24, Episode Reward_naive: -1273.00
# Ep. 63, Ep.Timesteps 24, Episode Reward: -1286.24Ep. 63, Ep.Timesteps 24, Episode Reward_naive: -1290.00
# Ep. 64, Ep.Timesteps 24, Episode Reward: -1343.02Ep. 64, Ep.Timesteps 24, Episode Reward_naive: -1341.00
# Ep. 65, Ep.Timesteps 24, Episode Reward: -1088.68Ep. 65, Ep.Timesteps 24, Episode Reward_naive: -1079.00
# Ep. 66, Ep.Timesteps 24, Episode Reward: -1356.40Ep. 66, Ep.Timesteps 24, Episode Reward_naive: -1344.00
# Ep. 67, Ep.Timesteps 24, Episode Reward: -1356.55Ep. 67, Ep.Timesteps 24, Episode Reward_naive: -1361.00
# Ep. 68, Ep.Timesteps 24, Episode Reward: -883.83Ep. 68, Ep.Timesteps 24, Episode Reward_naive: -940.00
# Ep. 69, Ep.Timesteps 24, Episode Reward: -1202.31Ep. 69, Ep.Timesteps 24, Episode Reward_naive: -1276.00
# Ep. 70, Ep.Timesteps 24, Episode Reward: -1224.14Ep. 70, Ep.Timesteps 24, Episode Reward_naive: -1292.00
# Ep. 71, Ep.Timesteps 24, Episode Reward: -1197.22Ep. 71, Ep.Timesteps 24, Episode Reward_naive: -1276.00
# Ep. 72, Ep.Timesteps 24, Episode Reward: -1129.07Ep. 72, Ep.Timesteps 24, Episode Reward_naive: -1198.00
# Ep. 73, Ep.Timesteps 24, Episode Reward: -1023.03Ep. 73, Ep.Timesteps 24, Episode Reward_naive: -1091.00
# Ep. 74, Ep.Timesteps 24, Episode Reward: -933.27Ep. 74, Ep.Timesteps 24, Episode Reward_naive: -977.00
# Ep. 75, Ep.Timesteps 24, Episode Reward: -1127.26Ep. 75, Ep.Timesteps 24, Episode Reward_naive: -1186.00
# Ep. 76, Ep.Timesteps 24, Episode Reward: -1101.60Ep. 76, Ep.Timesteps 24, Episode Reward_naive: -1160.00
# Ep. 77, Ep.Timesteps 24, Episode Reward: -1082.96Ep. 77, Ep.Timesteps 24, Episode Reward_naive: -1142.00
# Ep. 78, Ep.Timesteps 24, Episode Reward: -1165.94Ep. 78, Ep.Timesteps 24, Episode Reward_naive: -1220.00
# Ep. 79, Ep.Timesteps 24, Episode Reward: -856.39Ep. 79, Ep.Timesteps 24, Episode Reward_naive: -906.00
# Ep. 80, Ep.Timesteps 24, Episode Reward: -742.10Ep. 80, Ep.Timesteps 24, Episode Reward_naive: -788.00
# Ep. 81, Ep.Timesteps 24, Episode Reward: -1002.00Ep. 81, Ep.Timesteps 24, Episode Reward_naive: -1055.00
# Ep. 82, Ep.Timesteps 24, Episode Reward: -1020.93Ep. 82, Ep.Timesteps 24, Episode Reward_naive: -1083.00
# Ep. 83, Ep.Timesteps 24, Episode Reward: -1154.43Ep. 83, Ep.Timesteps 24, Episode Reward_naive: -1201.00
# Ep. 84, Ep.Timesteps 24, Episode Reward: -1208.39Ep. 84, Ep.Timesteps 24, Episode Reward_naive: -1205.00
# Ep. 85, Ep.Timesteps 24, Episode Reward: -1299.14Ep. 85, Ep.Timesteps 24, Episode Reward_naive: -1254.00
# Ep. 86, Ep.Timesteps 24, Episode Reward: -1120.18Ep. 86, Ep.Timesteps 24, Episode Reward_naive: -1102.00
# Ep. 87, Ep.Timesteps 24, Episode Reward: -1313.88Ep. 87, Ep.Timesteps 24, Episode Reward_naive: -1283.00
# Ep. 88, Ep.Timesteps 24, Episode Reward: -1227.12Ep. 88, Ep.Timesteps 24, Episode Reward_naive: -1202.00
# Ep. 89, Ep.Timesteps 24, Episode Reward: -905.06Ep. 89, Ep.Timesteps 24, Episode Reward_naive: -892.00
# Ep. 90, Ep.Timesteps 24, Episode Reward: -953.57Ep. 90, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 91, Ep.Timesteps 24, Episode Reward: -1040.73Ep. 91, Ep.Timesteps 24, Episode Reward_naive: -1004.00
# Ep. 92, Ep.Timesteps 24, Episode Reward: -1245.26Ep. 92, Ep.Timesteps 24, Episode Reward_naive: -1226.00
# Ep. 93, Ep.Timesteps 24, Episode Reward: -951.64Ep. 93, Ep.Timesteps 24, Episode Reward_naive: -969.00
# Ep. 94, Ep.Timesteps 24, Episode Reward: -1096.67Ep. 94, Ep.Timesteps 24, Episode Reward_naive: -1129.00
# Ep. 95, Ep.Timesteps 24, Episode Reward: -1077.12Ep. 95, Ep.Timesteps 24, Episode Reward_naive: -1115.00
# Ep. 96, Ep.Timesteps 24, Episode Reward: -1043.48Ep. 96, Ep.Timesteps 24, Episode Reward_naive: -1081.00
# Ep. 97, Ep.Timesteps 24, Episode Reward: -1108.36Ep. 97, Ep.Timesteps 24, Episode Reward_naive: -1154.00
# Ep. 98, Ep.Timesteps 24, Episode Reward: -941.98Ep. 98, Ep.Timesteps 24, Episode Reward_naive: -972.00
# Ep. 99, Ep.Timesteps 24, Episode Reward: -966.58Ep. 99, Ep.Timesteps 24, Episode Reward_naive: -991.00
# Ep. 100, Ep.Timesteps 24, Episode Reward: -1072.32Ep. 100, Ep.Timesteps 24, Episode Reward_naive: -1109.00
# Ep. 101, Ep.Timesteps 24, Episode Reward: -1008.57Ep. 101, Ep.Timesteps 24, Episode Reward_naive: -963.00
# Ep. 102, Ep.Timesteps 24, Episode Reward: -1271.28Ep. 102, Ep.Timesteps 24, Episode Reward_naive: -1208.00
# Ep. 103, Ep.Timesteps 24, Episode Reward: -981.79Ep. 103, Ep.Timesteps 24, Episode Reward_naive: -924.00
# Ep. 104, Ep.Timesteps 24, Episode Reward: -1154.34Ep. 104, Ep.Timesteps 24, Episode Reward_naive: -1088.00
# Ep. 105, Ep.Timesteps 24, Episode Reward: -1086.52Ep. 105, Ep.Timesteps 24, Episode Reward_naive: -1036.00
# Ep. 106, Ep.Timesteps 24, Episode Reward: -1316.03Ep. 106, Ep.Timesteps 24, Episode Reward_naive: -1251.00
# Ep. 107, Ep.Timesteps 24, Episode Reward: -1052.20Ep. 107, Ep.Timesteps 24, Episode Reward_naive: -1001.00
# Ep. 108, Ep.Timesteps 24, Episode Reward: -1174.20Ep. 108, Ep.Timesteps 24, Episode Reward_naive: -1112.00
# Ep. 109, Ep.Timesteps 24, Episode Reward: -1035.25Ep. 109, Ep.Timesteps 24, Episode Reward_naive: -1012.00
# Ep. 133, Ep.Timesteps 24, Episode Reward: -1168.03Ep. 133, Ep.Timesteps 24, Episode Reward_naive: -1148.00
# Ep. 134, Ep.Timesteps 24, Episode Reward: -1227.24Ep. 134, Ep.Timesteps 24, Episode Reward_naive: -1185.00
# Ep. 135, Ep.Timesteps 24, Episode Reward: -1168.22Ep. 135, Ep.Timesteps 24, Episode Reward_naive: -1120.00
# Ep. 136, Ep.Timesteps 24, Episode Reward: -1219.93Ep. 136, Ep.Timesteps 24, Episode Reward_naive: -1169.00
# Ep. 137, Ep.Timesteps 24, Episode Reward: -1229.06Ep. 137, Ep.Timesteps 24, Episode Reward_naive: -1172.00
# Ep. 138, Ep.Timesteps 24, Episode Reward: -972.50Ep. 138, Ep.Timesteps 24, Episode Reward_naive: -938.00
# Ep. 139, Ep.Timesteps 24, Episode Reward: -1214.96Ep. 139, Ep.Timesteps 24, Episode Reward_naive: -1139.00
# Ep. 140, Ep.Timesteps 24, Episode Reward: -1269.09Ep. 140, Ep.Timesteps 24, Episode Reward_naive: -1222.00
# Ep. 141, Ep.Timesteps 24, Episode Reward: -910.76Ep. 141, Ep.Timesteps 24, Episode Reward_naive: -879.00
# Ep. 142, Ep.Timesteps 24, Episode Reward: -1144.52Ep. 142, Ep.Timesteps 24, Episode Reward_naive: -1103.00
# Ep. 143, Ep.Timesteps 24, Episode Reward: -1203.93Ep. 143, Ep.Timesteps 24, Episode Reward_naive: -1195.00
# Ep. 144, Ep.Timesteps 24, Episode Reward: -1010.93Ep. 144, Ep.Timesteps 24, Episode Reward_naive: -1016.00
# Ep. 145, Ep.Timesteps 24, Episode Reward: -884.71Ep. 145, Ep.Timesteps 24, Episode Reward_naive: -898.00
# Ep. 146, Ep.Timesteps 24, Episode Reward: -1291.17Ep. 146, Ep.Timesteps 24, Episode Reward_naive: -1298.00
# Ep. 147, Ep.Timesteps 24, Episode Reward: -1157.02Ep. 147, Ep.Timesteps 24, Episode Reward_naive: -1146.00
# Ep. 148, Ep.Timesteps 24, Episode Reward: -884.05Ep. 148, Ep.Timesteps 24, Episode Reward_naive: -887.00
# Ep. 149, Ep.Timesteps 24, Episode Reward: -1120.64Ep. 149, Ep.Timesteps 24, Episode Reward_naive: -1107.00
# Ep. 150, Ep.Timesteps 24, Episode Reward: -1348.58Ep. 150, Ep.Timesteps 24, Episode Reward_naive: -1345.00
# Ep. 151, Ep.Timesteps 24, Episode Reward: -1132.89Ep. 151, Ep.Timesteps 24, Episode Reward_naive: -1216.00
# Ep. 152, Ep.Timesteps 24, Episode Reward: -1156.10Ep. 152, Ep.Timesteps 24, Episode Reward_naive: -1229.00
# Ep. 153, Ep.Timesteps 24, Episode Reward: -1062.36Ep. 153, Ep.Timesteps 24, Episode Reward_naive: -1135.00
# Ep. 154, Ep.Timesteps 24, Episode Reward: -1120.81Ep. 154, Ep.Timesteps 24, Episode Reward_naive: -1185.00
# Ep. 155, Ep.Timesteps 24, Episode Reward: -1294.54Ep. 155, Ep.Timesteps 24, Episode Reward_naive: -1374.00
# Ep. 156, Ep.Timesteps 24, Episode Reward: -998.96Ep. 156, Ep.Timesteps 24, Episode Reward_naive: -1065.00
# Ep. 157, Ep.Timesteps 24, Episode Reward: -1048.57Ep. 157, Ep.Timesteps 24, Episode Reward_naive: -1116.00
# Ep. 158, Ep.Timesteps 24, Episode Reward: -951.96Ep. 158, Ep.Timesteps 24, Episode Reward_naive: -1014.00
# Ep. 159, Ep.Timesteps 24, Episode Reward: -1578.96Ep. 159, Ep.Timesteps 24, Episode Reward_naive: -1678.00
# Ep. 160, Ep.Timesteps 24, Episode Reward: -790.37Ep. 160, Ep.Timesteps 24, Episode Reward_naive: -857.00
# Ep. 161, Ep.Timesteps 24, Episode Reward: -1063.41Ep. 161, Ep.Timesteps 24, Episode Reward_naive: -1135.00
# Ep. 162, Ep.Timesteps 24, Episode Reward: -1288.03Ep. 162, Ep.Timesteps 24, Episode Reward_naive: -1376.00
# Ep. 163, Ep.Timesteps 24, Episode Reward: -858.37Ep. 163, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 164, Ep.Timesteps 24, Episode Reward: -775.01Ep. 164, Ep.Timesteps 24, Episode Reward_naive: -839.00
# Ep. 165, Ep.Timesteps 24, Episode Reward: -1174.71Ep. 165, Ep.Timesteps 24, Episode Reward_naive: -1253.00
# Ep. 166, Ep.Timesteps 24, Episode Reward: -987.95Ep. 166, Ep.Timesteps 24, Episode Reward_naive: -1069.00
# Ep. 167, Ep.Timesteps 24, Episode Reward: -1259.15Ep. 167, Ep.Timesteps 24, Episode Reward_naive: -1352.00
# Ep. 168, Ep.Timesteps 24, Episode Reward: -1045.31Ep. 168, Ep.Timesteps 24, Episode Reward_naive: -1101.00
# Ep. 169, Ep.Timesteps 24, Episode Reward: -995.97Ep. 169, Ep.Timesteps 24, Episode Reward_naive: -1070.00
# Ep. 170, Ep.Timesteps 24, Episode Reward: -1099.00Ep. 170, Ep.Timesteps 24, Episode Reward_naive: -1164.00
# Ep. 171, Ep.Timesteps 24, Episode Reward: -877.32Ep. 171, Ep.Timesteps 24, Episode Reward_naive: -928.00
# Ep. 172, Ep.Timesteps 24, Episode Reward: -1093.63Ep. 172, Ep.Timesteps 24, Episode Reward_naive: -1160.00
# Ep. 173, Ep.Timesteps 24, Episode Reward: -1108.94Ep. 173, Ep.Timesteps 24, Episode Reward_naive: -1186.00
# Ep. 174, Ep.Timesteps 24, Episode Reward: -980.49Ep. 174, Ep.Timesteps 24, Episode Reward_naive: -1056.00
# Ep. 175, Ep.Timesteps 24, Episode Reward: -1212.95Ep. 175, Ep.Timesteps 24, Episode Reward_naive: -1288.00
# Ep. 176, Ep.Timesteps 24, Episode Reward: -1142.55Ep. 176, Ep.Timesteps 24, Episode Reward_naive: -1184.00
# Ep. 177, Ep.Timesteps 24, Episode Reward: -988.68Ep. 177, Ep.Timesteps 24, Episode Reward_naive: -1028.00
# Ep. 178, Ep.Timesteps 24, Episode Reward: -805.58Ep. 178, Ep.Timesteps 24, Episode Reward_naive: -838.00
# Ep. 247, Ep.Timesteps 24, Episode Reward: -1108.80Ep. 247, Ep.Timesteps 24, Episode Reward_naive: -1080.00
# Ep. 248, Ep.Timesteps 24, Episode Reward: -1008.40Ep. 248, Ep.Timesteps 24, Episode Reward_naive: -983.00
# Ep. 249, Ep.Timesteps 24, Episode Reward: -1107.63Ep. 249, Ep.Timesteps 24, Episode Reward_naive: -1088.00
# Ep. 250, Ep.Timesteps 24, Episode Reward: -1278.19Ep. 250, Ep.Timesteps 24, Episode Reward_naive: -1239.00
# Ep. 251, Ep.Timesteps 24, Episode Reward: -1262.38Ep. 251, Ep.Timesteps 24, Episode Reward_naive: -1222.00
# Ep. 252, Ep.Timesteps 24, Episode Reward: -1022.76Ep. 252, Ep.Timesteps 24, Episode Reward_naive: -992.00
# Ep. 253, Ep.Timesteps 24, Episode Reward: -981.00Ep. 253, Ep.Timesteps 24, Episode Reward_naive: -944.00
# Ep. 254, Ep.Timesteps 24, Episode Reward: -810.99Ep. 254, Ep.Timesteps 24, Episode Reward_naive: -794.00
# Ep. 255, Ep.Timesteps 24, Episode Reward: -1229.02Ep. 255, Ep.Timesteps 24, Episode Reward_naive: -1188.00
# Ep. 256, Ep.Timesteps 24, Episode Reward: -1113.76Ep. 256, Ep.Timesteps 24, Episode Reward_naive: -1077.00
# Ep. 257, Ep.Timesteps 24, Episode Reward: -1284.47Ep. 257, Ep.Timesteps 24, Episode Reward_naive: -1253.00
# Ep. 258, Ep.Timesteps 24, Episode Reward: -954.36Ep. 258, Ep.Timesteps 24, Episode Reward_naive: -924.00
# Ep. 259, Ep.Timesteps 24, Episode Reward: -1218.09Ep. 259, Ep.Timesteps 24, Episode Reward_naive: -1158.00
# Ep. 260, Ep.Timesteps 24, Episode Reward: -1194.20Ep. 260, Ep.Timesteps 24, Episode Reward_naive: -1155.00
# Ep. 261, Ep.Timesteps 24, Episode Reward: -1392.16Ep. 261, Ep.Timesteps 24, Episode Reward_naive: -1328.00
# Ep. 262, Ep.Timesteps 24, Episode Reward: -1205.89Ep. 262, Ep.Timesteps 24, Episode Reward_naive: -1170.00
# Ep. 263, Ep.Timesteps 24, Episode Reward: -1113.74Ep. 263, Ep.Timesteps 24, Episode Reward_naive: -1072.00
# Ep. 264, Ep.Timesteps 24, Episode Reward: -1441.55Ep. 264, Ep.Timesteps 24, Episode Reward_naive: -1374.00
# Ep. 265, Ep.Timesteps 24, Episode Reward: -1292.84Ep. 265, Ep.Timesteps 24, Episode Reward_naive: -1230.00
# Ep. 266, Ep.Timesteps 24, Episode Reward: -1121.85Ep. 266, Ep.Timesteps 24, Episode Reward_naive: -1067.00
# Ep. 267, Ep.Timesteps 24, Episode Reward: -1393.29Ep. 267, Ep.Timesteps 24, Episode Reward_naive: -1321.00
# Ep. 268, Ep.Timesteps 24, Episode Reward: -1062.43Ep. 268, Ep.Timesteps 24, Episode Reward_naive: -999.00
# Ep. 269, Ep.Timesteps 24, Episode Reward: -1178.40Ep. 269, Ep.Timesteps 24, Episode Reward_naive: -1110.00
# Ep. 315, Ep.Timesteps 24, Episode Reward: -1026.10Ep. 315, Ep.Timesteps 24, Episode Reward_naive: -1023.00
# Ep. 316, Ep.Timesteps 24, Episode Reward: -1062.03Ep. 316, Ep.Timesteps 24, Episode Reward_naive: -1069.00
# Ep. 317, Ep.Timesteps 24, Episode Reward: -1152.19Ep. 317, Ep.Timesteps 24, Episode Reward_naive: -1136.00
# Ep. 318, Ep.Timesteps 24, Episode Reward: -960.32Ep. 318, Ep.Timesteps 24, Episode Reward_naive: -949.00
# Ep. 319, Ep.Timesteps 24, Episode Reward: -946.61Ep. 319, Ep.Timesteps 24, Episode Reward_naive: -956.00
# Ep. 320, Ep.Timesteps 24, Episode Reward: -880.99Ep. 320, Ep.Timesteps 24, Episode Reward_naive: -879.00
# Ep. 321, Ep.Timesteps 24, Episode Reward: -1101.93Ep. 321, Ep.Timesteps 24, Episode Reward_naive: -1105.00
# Ep. 322, Ep.Timesteps 24, Episode Reward: -1256.82Ep. 322, Ep.Timesteps 24, Episode Reward_naive: -1253.00
# Ep. 323, Ep.Timesteps 24, Episode Reward: -893.64Ep. 323, Ep.Timesteps 24, Episode Reward_naive: -911.00
# Ep. 324, Ep.Timesteps 24, Episode Reward: -1102.32Ep. 324, Ep.Timesteps 24, Episode Reward_naive: -1096.00
# Ep. 325, Ep.Timesteps 24, Episode Reward: -973.29Ep. 325, Ep.Timesteps 24, Episode Reward_naive: -982.00
# Ep. 326, Ep.Timesteps 24, Episode Reward: -1319.61Ep. 326, Ep.Timesteps 24, Episode Reward_naive: -1260.00
# Ep. 327, Ep.Timesteps 24, Episode Reward: -1059.49Ep. 327, Ep.Timesteps 24, Episode Reward_naive: -1011.00
# Ep. 328, Ep.Timesteps 24, Episode Reward: -1032.93Ep. 328, Ep.Timesteps 24, Episode Reward_naive: -981.00
# Ep. 329, Ep.Timesteps 24, Episode Reward: -961.60Ep. 329, Ep.Timesteps 24, Episode Reward_naive: -917.00
# Ep. 330, Ep.Timesteps 24, Episode Reward: -957.21Ep. 330, Ep.Timesteps 24, Episode Reward_naive: -898.00
# Ep. 331, Ep.Timesteps 24, Episode Reward: -1111.37Ep. 331, Ep.Timesteps 24, Episode Reward_naive: -1055.00
# Ep. 332, Ep.Timesteps 24, Episode Reward: -971.46Ep. 332, Ep.Timesteps 24, Episode Reward_naive: -929.00
# Ep. 333, Ep.Timesteps 24, Episode Reward: -1035.87Ep. 333, Ep.Timesteps 24, Episode Reward_naive: -989.00
# Ep. 334, Ep.Timesteps 24, Episode Reward: -1137.77Ep. 334, Ep.Timesteps 24, Episode Reward_naive: -1074.00
# Ep. 335, Ep.Timesteps 24, Episode Reward: -1228.95Ep. 335, Ep.Timesteps 24, Episode Reward_naive: -1156.00
# Ep. 336, Ep.Timesteps 24, Episode Reward: -1015.97Ep. 336, Ep.Timesteps 24, Episode Reward_naive: -967.00
# Ep. 337, Ep.Timesteps 24, Episode Reward: -926.87Ep. 337, Ep.Timesteps 24, Episode Reward_naive: -889.00
# Ep. 338, Ep.Timesteps 24, Episode Reward: -1141.43Ep. 338, Ep.Timesteps 24, Episode Reward_naive: -1085.00
# Ep. 339, Ep.Timesteps 24, Episode Reward: -1204.15Ep. 339, Ep.Timesteps 24, Episode Reward_naive: -1146.00
# Ep. 340, Ep.Timesteps 24, Episode Reward: -1007.23Ep. 340, Ep.Timesteps 24, Episode Reward_naive: -956.00
# Ep. 341, Ep.Timesteps 24, Episode Reward: -1219.05Ep. 341, Ep.Timesteps 24, Episode Reward_naive: -1150.00
# Ep. 342, Ep.Timesteps 24, Episode Reward: -1103.51Ep. 342, Ep.Timesteps 24, Episode Reward_naive: -1052.00
# Ep. 343, Ep.Timesteps 24, Episode Reward: -820.52Ep. 343, Ep.Timesteps 24, Episode Reward_naive: -771.00
# Ep. 344, Ep.Timesteps 24, Episode Reward: -906.20Ep. 344, Ep.Timesteps 24, Episode Reward_naive: -863.00
# Ep. 345, Ep.Timesteps 24, Episode Reward: -921.67Ep. 345, Ep.Timesteps 24, Episode Reward_naive: -866.00
# Ep. 346, Ep.Timesteps 24, Episode Reward: -950.80Ep. 346, Ep.Timesteps 24, Episode Reward_naive: -891.00
# Ep. 347, Ep.Timesteps 24, Episode Reward: -1117.30Ep. 347, Ep.Timesteps 24, Episode Reward_naive: -1043.00
# Ep. 348, Ep.Timesteps 24, Episode Reward: -940.58Ep. 348, Ep.Timesteps 24, Episode Reward_naive: -884.00
# Ep. 349, Ep.Timesteps 24, Episode Reward: -986.62Ep. 349, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 350, Ep.Timesteps 24, Episode Reward: -1082.92Ep. 350, Ep.Timesteps 24, Episode Reward_naive: -1018.00
# Ep. 351, Ep.Timesteps 24, Episode Reward: -1104.72Ep. 351, Ep.Timesteps 24, Episode Reward_naive: -1008.00
# Ep. 352, Ep.Timesteps 24, Episode Reward: -1193.25Ep. 352, Ep.Timesteps 24, Episode Reward_naive: -1103.00
# Ep. 353, Ep.Timesteps 24, Episode Reward: -1068.22Ep. 353, Ep.Timesteps 24, Episode Reward_naive: -1003.00
# Ep. 354, Ep.Timesteps 24, Episode Reward: -1370.83Ep. 354, Ep.Timesteps 24, Episode Reward_naive: -1276.00
# Ep. 355, Ep.Timesteps 24, Episode Reward: -1512.64Ep. 355, Ep.Timesteps 24, Episode Reward_naive: -1407.00
# Ep. 356, Ep.Timesteps 24, Episode Reward: -955.32Ep. 356, Ep.Timesteps 24, Episode Reward_naive: -900.00
# Ep. 357, Ep.Timesteps 24, Episode Reward: -950.52Ep. 357, Ep.Timesteps 24, Episode Reward_naive: -901.00
# Ep. 358, Ep.Timesteps 24, Episode Reward: -1130.57Ep. 358, Ep.Timesteps 24, Episode Reward_naive: -1065.00
# Ep. 359, Ep.Timesteps 24, Episode Reward: -1188.93Ep. 359, Ep.Timesteps 24, Episode Reward_naive: -1117.00
# Ep. 360, Ep.Timesteps 24, Episode Reward: -1221.25Ep. 360, Ep.Timesteps 24, Episode Reward_naive: -1143.00
# Ep. 384, Ep.Timesteps 24, Episode Reward: -1263.17Ep. 384, Ep.Timesteps 24, Episode Reward_naive: -1182.00
# Ep. 385, Ep.Timesteps 24, Episode Reward: -1323.89Ep. 385, Ep.Timesteps 24, Episode Reward_naive: -1213.00
# Ep. 386, Ep.Timesteps 24, Episode Reward: -950.02Ep. 386, Ep.Timesteps 24, Episode Reward_naive: -890.00
# Ep. 387, Ep.Timesteps 24, Episode Reward: -1341.66Ep. 387, Ep.Timesteps 24, Episode Reward_naive: -1230.00
# Ep. 388, Ep.Timesteps 24, Episode Reward: -1002.47Ep. 388, Ep.Timesteps 24, Episode Reward_naive: -939.00
# Ep. 389, Ep.Timesteps 24, Episode Reward: -941.34Ep. 389, Ep.Timesteps 24, Episode Reward_naive: -875.00
# Ep. 390, Ep.Timesteps 24, Episode Reward: -1095.89Ep. 390, Ep.Timesteps 24, Episode Reward_naive: -1015.00
# Ep. 391, Ep.Timesteps 24, Episode Reward: -1128.19Ep. 391, Ep.Timesteps 24, Episode Reward_naive: -1045.00
# Ep. 392, Ep.Timesteps 24, Episode Reward: -1103.65Ep. 392, Ep.Timesteps 24, Episode Reward_naive: -1022.00
# Ep. 393, Ep.Timesteps 24, Episode Reward: -902.41Ep. 393, Ep.Timesteps 24, Episode Reward_naive: -824.00
# Ep. 394, Ep.Timesteps 24, Episode Reward: -1143.84Ep. 394, Ep.Timesteps 24, Episode Reward_naive: -1063.00
# Ep. 395, Ep.Timesteps 24, Episode Reward: -1202.42Ep. 395, Ep.Timesteps 24, Episode Reward_naive: -1106.00
# Ep. 396, Ep.Timesteps 24, Episode Reward: -1419.56Ep. 396, Ep.Timesteps 24, Episode Reward_naive: -1305.00
# Ep. 397, Ep.Timesteps 24, Episode Reward: -972.76Ep. 397, Ep.Timesteps 24, Episode Reward_naive: -905.00
# Ep. 398, Ep.Timesteps 24, Episode Reward: -1239.04Ep. 398, Ep.Timesteps 24, Episode Reward_naive: -1131.00
# Ep. 399, Ep.Timesteps 24, Episode Reward: -1261.57Ep. 399, Ep.Timesteps 24, Episode Reward_naive: -1171.00
# Ep. 400, Ep.Timesteps 24, Episode Reward: -1209.68Ep. 400, Ep.Timesteps 24, Episode Reward_naive: -1105.00
# Ep. 401, Ep.Timesteps 24, Episode Reward: -689.62Ep. 401, Ep.Timesteps 24, Episode Reward_naive: -644.00
# Ep. 402, Ep.Timesteps 24, Episode Reward: -1052.51Ep. 402, Ep.Timesteps 24, Episode Reward_naive: -976.00
# Ep. 403, Ep.Timesteps 24, Episode Reward: -1059.68Ep. 403, Ep.Timesteps 24, Episode Reward_naive: -987.00
# Ep. 404, Ep.Timesteps 24, Episode Reward: -1025.09Ep. 404, Ep.Timesteps 24, Episode Reward_naive: -954.00
# Ep. 405, Ep.Timesteps 24, Episode Reward: -807.06Ep. 405, Ep.Timesteps 24, Episode Reward_naive: -767.00
# Ep. 406, Ep.Timesteps 24, Episode Reward: -1331.80Ep. 406, Ep.Timesteps 24, Episode Reward_naive: -1232.00
# ...
# Ep. 2786, Ep.Timesteps 24, Episode Reward: -1002.57Ep. 2786, Ep.Timesteps 24, Episode Reward_naive: -1099.00
# Ep. 2787, Ep.Timesteps 24, Episode Reward: -923.34Ep. 2787, Ep.Timesteps 24, Episode Reward_naive: -1022.00
# Ep. 2788, Ep.Timesteps 24, Episode Reward: -1033.17Ep. 2788, Ep.Timesteps 24, Episode Reward_naive: -1132.00
# Ep. 2789, Ep.Timesteps 24, Episode Reward: -1001.58Ep. 2789, Ep.Timesteps 24, Episode Reward_naive: -1111.00
# Ep. 2790, Ep.Timesteps 24, Episode Reward: -950.06Ep. 2790, Ep.Timesteps 24, Episode Reward_naive: -1054.00
# Ep. 2791, Ep.Timesteps 24, Episode Reward: -842.57Ep. 2791, Ep.Timesteps 24, Episode Reward_naive: -932.00
# Ep. 2792, Ep.Timesteps 24, Episode Reward: -1049.82Ep. 2792, Ep.Timesteps 24, Episode Reward_naive: -1148.00
# Ep. 2793, Ep.Timesteps 24, Episode Reward: -809.82Ep. 2793, Ep.Timesteps 24, Episode Reward_naive: -897.00
# Ep. 2794, Ep.Timesteps 24, Episode Reward: -1174.95Ep. 2794, Ep.Timesteps 24, Episode Reward_naive: -1300.00
# Ep. 2795, Ep.Timesteps 24, Episode Reward: -937.66Ep. 2795, Ep.Timesteps 24, Episode Reward_naive: -1028.00
# Ep. 2796, Ep.Timesteps 24, Episode Reward: -872.81Ep. 2796, Ep.Timesteps 24, Episode Reward_naive: -956.00
# Ep. 2797, Ep.Timesteps 24, Episode Reward: -985.96Ep. 2797, Ep.Timesteps 24, Episode Reward_naive: -1083.00
# Ep. 2798, Ep.Timesteps 24, Episode Reward: -923.14Ep. 2798, Ep.Timesteps 24, Episode Reward_naive: -1013.00
# Ep. 2799, Ep.Timesteps 24, Episode Reward: -1001.83Ep. 2799, Ep.Timesteps 24, Episode Reward_naive: -1105.00
# Ep. 2800, Ep.Timesteps 24, Episode Reward: -767.84Ep. 2800, Ep.Timesteps 24, Episode Reward_naive: -850.00
# Ep. 2801, Ep.Timesteps 24, Episode Reward: -870.73Ep. 2801, Ep.Timesteps 24, Episode Reward_naive: -968.00
# Ep. 2802, Ep.Timesteps 24, Episode Reward: -936.22Ep. 2802, Ep.Timesteps 24, Episode Reward_naive: -1028.00
# Ep. 2803, Ep.Timesteps 24, Episode Reward: -929.96Ep. 2803, Ep.Timesteps 24, Episode Reward_naive: -1015.00
# Ep. 2804, Ep.Timesteps 24, Episode Reward: -807.87Ep. 2804, Ep.Timesteps 24, Episode Reward_naive: -884.00
# Ep. 2805, Ep.Timesteps 24, Episode Reward: -1196.56Ep. 2805, Ep.Timesteps 24, Episode Reward_naive: -1311.00
# Ep. 2806, Ep.Timesteps 24, Episode Reward: -1004.39Ep. 2806, Ep.Timesteps 24, Episode Reward_naive: -1110.00
# Ep. 2807, Ep.Timesteps 24, Episode Reward: -1074.02Ep. 2807, Ep.Timesteps 24, Episode Reward_naive: -1190.00
# Ep. 2808, Ep.Timesteps 24, Episode Reward: -895.00Ep. 2808, Ep.Timesteps 24, Episode Reward_naive: -977.00
# Ep. 2809, Ep.Timesteps 24, Episode Reward: -1044.31Ep. 2809, Ep.Timesteps 24, Episode Reward_naive: -1144.00
# Ep. 2810, Ep.Timesteps 24, Episode Reward: -1070.77Ep. 2810, Ep.Timesteps 24, Episode Reward_naive: -1168.00
# Ep. 2811, Ep.Timesteps 24, Episode Reward: -1021.33Ep. 2811, Ep.Timesteps 24, Episode Reward_naive: -1112.00
# Ep. 2812, Ep.Timesteps 24, Episode Reward: -914.27Ep. 2812, Ep.Timesteps 24, Episode Reward_naive: -990.00
# Ep. 2813, Ep.Timesteps 24, Episode Reward: -967.40Ep. 2813, Ep.Timesteps 24, Episode Reward_naive: -1062.00
# Ep. 2814, Ep.Timesteps 24, Episode Reward: -997.26Ep. 2814, Ep.Timesteps 24, Episode Reward_naive: -1109.00
# Ep. 2815, Ep.Timesteps 24, Episode Reward: -1036.91Ep. 2815, Ep.Timesteps 24, Episode Reward_naive: -1138.00
# Ep. 2816, Ep.Timesteps 24, Episode Reward: -830.04Ep. 2816, Ep.Timesteps 24, Episode Reward_naive: -911.00
# Ep. 2817, Ep.Timesteps 24, Episode Reward: -786.42Ep. 2817, Ep.Timesteps 24, Episode Reward_naive: -876.00
# Ep. 2818, Ep.Timesteps 24, Episode Reward: -906.48Ep. 2818, Ep.Timesteps 24, Episode Reward_naive: -1002.00
# Ep. 2819, Ep.Timesteps 24, Episode Reward: -1032.46Ep. 2819, Ep.Timesteps 24, Episode Reward_naive: -1141.00
# Ep. 2820, Ep.Timesteps 24, Episode Reward: -855.67Ep. 2820, Ep.Timesteps 24, Episode Reward_naive: -943.00
# Ep. 2821, Ep.Timesteps 24, Episode Reward: -846.38Ep. 2821, Ep.Timesteps 24, Episode Reward_naive: -930.00
# Ep. 2822, Ep.Timesteps 24, Episode Reward: -883.55Ep. 2822, Ep.Timesteps 24, Episode Reward_naive: -978.00
# Ep. 2823, Ep.Timesteps 24, Episode Reward: -874.14Ep. 2823, Ep.Timesteps 24, Episode Reward_naive: -973.00
# Ep. 2824, Ep.Timesteps 24, Episode Reward: -998.76Ep. 2824, Ep.Timesteps 24, Episode Reward_naive: -1119.00
# Ep. 2825, Ep.Timesteps 24, Episode Reward: -1016.95Ep. 2825, Ep.Timesteps 24, Episode Reward_naive: -1121.00
# Ep. 2826, Ep.Timesteps 24, Episode Reward: -920.32Ep. 2826, Ep.Timesteps 24, Episode Reward_naive: -1023.00
# Ep. 2827, Ep.Timesteps 24, Episode Reward: -831.20Ep. 2827, Ep.Timesteps 24, Episode Reward_naive: -918.00
# Ep. 2828, Ep.Timesteps 24, Episode Reward: -828.73Ep. 2828, Ep.Timesteps 24, Episode Reward_naive: -905.00
# Ep. 2829, Ep.Timesteps 24, Episode Reward: -1008.28Ep. 2829, Ep.Timesteps 24, Episode Reward_naive: -1113.00
# Ep. 2830, Ep.Timesteps 24, Episode Reward: -1034.61Ep. 2830, Ep.Timesteps 24, Episode Reward_naive: -1130.00
# Ep. 2831, Ep.Timesteps 24, Episode Reward: -1031.85Ep. 2831, Ep.Timesteps 24, Episode Reward_naive: -1149.00
# Ep. 2832, Ep.Timesteps 24, Episode Reward: -900.34Ep. 2832, Ep.Timesteps 24, Episode Reward_naive: -1001.00
# Ep. 2833, Ep.Timesteps 24, Episode Reward: -640.09Ep. 2833, Ep.Timesteps 24, Episode Reward_naive: -702.00
# Ep. 2834, Ep.Timesteps 24, Episode Reward: -764.34Ep. 2834, Ep.Timesteps 24, Episode Reward_naive: -843.00
# Ep. 2835, Ep.Timesteps 24, Episode Reward: -838.05Ep. 2835, Ep.Timesteps 24, Episode Reward_naive: -917.00
# Ep. 2836, Ep.Timesteps 24, Episode Reward: -818.53Ep. 2836, Ep.Timesteps 24, Episode Reward_naive: -902.00
# Ep. 2837, Ep.Timesteps 24, Episode Reward: -687.66Ep. 2837, Ep.Timesteps 24, Episode Reward_naive: -762.00
# Ep. 2838, Ep.Timesteps 24, Episode Reward: -709.07Ep. 2838, Ep.Timesteps 24, Episode Reward_naive: -768.00
# Ep. 2839, Ep.Timesteps 24, Episode Reward: -891.73Ep. 2839, Ep.Timesteps 24, Episode Reward_naive: -964.00
# Ep. 2840, Ep.Timesteps 24, Episode Reward: -874.55Ep. 2840, Ep.Timesteps 24, Episode Reward_naive: -960.00
# Ep. 2841, Ep.Timesteps 24, Episode Reward: -748.19Ep. 2841, Ep.Timesteps 24, Episode Reward_naive: -833.00
# Ep. 2842, Ep.Timesteps 24, Episode Reward: -799.51Ep. 2842, Ep.Timesteps 24, Episode Reward_naive: -878.00
# Ep. 2843, Ep.Timesteps 24, Episode Reward: -944.22Ep. 2843, Ep.Timesteps 24, Episode Reward_naive: -1035.00
# Ep. 2844, Ep.Timesteps 24, Episode Reward: -1142.92Ep. 2844, Ep.Timesteps 24, Episode Reward_naive: -1260.00
# Ep. 2845, Ep.Timesteps 24, Episode Reward: -832.37Ep. 2845, Ep.Timesteps 24, Episode Reward_naive: -918.00
# Ep. 2846, Ep.Timesteps 24, Episode Reward: -967.11Ep. 2846, Ep.Timesteps 24, Episode Reward_naive: -1070.00
# Ep. 2847, Ep.Timesteps 24, Episode Reward: -993.43Ep. 2847, Ep.Timesteps 24, Episode Reward_naive: -1100.00
# Ep. 2848, Ep.Timesteps 24, Episode Reward: -1195.95Ep. 2848, Ep.Timesteps 24, Episode Reward_naive: -1313.00
# Ep. 2849, Ep.Timesteps 24, Episode Reward: -898.82Ep. 2849, Ep.Timesteps 24, Episode Reward_naive: -1001.00
# Ep. 2850, Ep.Timesteps 24, Episode Reward: -804.13Ep. 2850, Ep.Timesteps 24, Episode Reward_naive: -891.00
# Ep. 2851, Ep.Timesteps 24, Episode Reward: -935.06Ep. 2851, Ep.Timesteps 24, Episode Reward_naive: -1025.00
# Ep. 2852, Ep.Timesteps 24, Episode Reward: -858.00Ep. 2852, Ep.Timesteps 24, Episode Reward_naive: -955.00
# Ep. 2875, Ep.Timesteps 24, Episode Reward: -670.18Ep. 2875, Ep.Timesteps 24, Episode Reward_naive: -731.00
# Ep. 2876, Ep.Timesteps 24, Episode Reward: -790.92Ep. 2876, Ep.Timesteps 24, Episode Reward_naive: -876.00
# Ep. 2877, Ep.Timesteps 24, Episode Reward: -826.11Ep. 2877, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 2878, Ep.Timesteps 24, Episode Reward: -872.09Ep. 2878, Ep.Timesteps 24, Episode Reward_naive: -956.00
# Ep. 2879, Ep.Timesteps 24, Episode Reward: -924.28Ep. 2879, Ep.Timesteps 24, Episode Reward_naive: -1017.00
# Ep. 2880, Ep.Timesteps 24, Episode Reward: -879.28Ep. 2880, Ep.Timesteps 24, Episode Reward_naive: -971.00
# Ep. 2881, Ep.Timesteps 24, Episode Reward: -960.88Ep. 2881, Ep.Timesteps 24, Episode Reward_naive: -1055.00
# Ep. 2882, Ep.Timesteps 24, Episode Reward: -840.12Ep. 2882, Ep.Timesteps 24, Episode Reward_naive: -924.00
# Ep. 2883, Ep.Timesteps 24, Episode Reward: -941.05Ep. 2883, Ep.Timesteps 24, Episode Reward_naive: -1030.00
# Ep. 2884, Ep.Timesteps 24, Episode Reward: -1158.21Ep. 2884, Ep.Timesteps 24, Episode Reward_naive: -1283.00
# Ep. 2885, Ep.Timesteps 24, Episode Reward: -1038.10Ep. 2885, Ep.Timesteps 24, Episode Reward_naive: -1149.00
# Ep. 2886, Ep.Timesteps 24, Episode Reward: -750.09Ep. 2886, Ep.Timesteps 24, Episode Reward_naive: -833.00
# Ep. 2887, Ep.Timesteps 24, Episode Reward: -972.22Ep. 2887, Ep.Timesteps 24, Episode Reward_naive: -1077.00
# Ep. 2888, Ep.Timesteps 24, Episode Reward: -1027.56Ep. 2888, Ep.Timesteps 24, Episode Reward_naive: -1121.00
# Ep. 2889, Ep.Timesteps 24, Episode Reward: -882.27Ep. 2889, Ep.Timesteps 24, Episode Reward_naive: -960.00
# Ep. 2890, Ep.Timesteps 24, Episode Reward: -911.57Ep. 2890, Ep.Timesteps 24, Episode Reward_naive: -1017.00
# Ep. 2891, Ep.Timesteps 24, Episode Reward: -921.14Ep. 2891, Ep.Timesteps 24, Episode Reward_naive: -1020.00
# Ep. 2892, Ep.Timesteps 24, Episode Reward: -897.31Ep. 2892, Ep.Timesteps 24, Episode Reward_naive: -989.00
# Ep. 2893, Ep.Timesteps 24, Episode Reward: -892.05Ep. 2893, Ep.Timesteps 24, Episode Reward_naive: -989.00
# Ep. 2894, Ep.Timesteps 24, Episode Reward: -724.95Ep. 2894, Ep.Timesteps 24, Episode Reward_naive: -805.00
# Ep. 2895, Ep.Timesteps 24, Episode Reward: -803.81Ep. 2895, Ep.Timesteps 24, Episode Reward_naive: -881.00
# Ep. 2896, Ep.Timesteps 24, Episode Reward: -832.44Ep. 2896, Ep.Timesteps 24, Episode Reward_naive: -922.00
# Ep. 2897, Ep.Timesteps 24, Episode Reward: -932.56Ep. 2897, Ep.Timesteps 24, Episode Reward_naive: -1036.00
# Ep. 2898, Ep.Timesteps 24, Episode Reward: -874.89Ep. 2898, Ep.Timesteps 24, Episode Reward_naive: -974.00
# Ep. 2899, Ep.Timesteps 24, Episode Reward: -858.69Ep. 2899, Ep.Timesteps 24, Episode Reward_naive: -949.00
# Ep. 2900, Ep.Timesteps 24, Episode Reward: -998.54Ep. 2900, Ep.Timesteps 24, Episode Reward_naive: -1107.00
# Ep. 2901, Ep.Timesteps 24, Episode Reward: -982.32Ep. 2901, Ep.Timesteps 24, Episode Reward_naive: -1092.00
# Ep. 2902, Ep.Timesteps 24, Episode Reward: -813.33Ep. 2902, Ep.Timesteps 24, Episode Reward_naive: -888.00
# Ep. 2903, Ep.Timesteps 24, Episode Reward: -817.93Ep. 2903, Ep.Timesteps 24, Episode Reward_naive: -899.00
# Ep. 2904, Ep.Timesteps 24, Episode Reward: -946.98Ep. 2904, Ep.Timesteps 24, Episode Reward_naive: -1044.00
# Ep. 2905, Ep.Timesteps 24, Episode Reward: -1061.39Ep. 2905, Ep.Timesteps 24, Episode Reward_naive: -1186.00
# Ep. 2906, Ep.Timesteps 24, Episode Reward: -775.84Ep. 2906, Ep.Timesteps 24, Episode Reward_naive: -849.00
# Ep. 2907, Ep.Timesteps 24, Episode Reward: -876.05Ep. 2907, Ep.Timesteps 24, Episode Reward_naive: -955.00
# Ep. 2908, Ep.Timesteps 24, Episode Reward: -1012.84Ep. 2908, Ep.Timesteps 24, Episode Reward_naive: -1121.00
# Ep. 2909, Ep.Timesteps 24, Episode Reward: -1019.50Ep. 2909, Ep.Timesteps 24, Episode Reward_naive: -1121.00
# Ep. 2910, Ep.Timesteps 24, Episode Reward: -927.25Ep. 2910, Ep.Timesteps 24, Episode Reward_naive: -1021.00
# Ep. 2911, Ep.Timesteps 24, Episode Reward: -1052.01Ep. 2911, Ep.Timesteps 24, Episode Reward_naive: -1160.00
# Ep. 2912, Ep.Timesteps 24, Episode Reward: -896.03Ep. 2912, Ep.Timesteps 24, Episode Reward_naive: -997.00
# Ep. 2913, Ep.Timesteps 24, Episode Reward: -1068.68Ep. 2913, Ep.Timesteps 24, Episode Reward_naive: -1174.00
# Ep. 2914, Ep.Timesteps 24, Episode Reward: -862.42Ep. 2914, Ep.Timesteps 24, Episode Reward_naive: -956.00
# Ep. 2915, Ep.Timesteps 24, Episode Reward: -972.64Ep. 2915, Ep.Timesteps 24, Episode Reward_naive: -1090.00
# Ep. 2916, Ep.Timesteps 24, Episode Reward: -1176.76Ep. 2916, Ep.Timesteps 24, Episode Reward_naive: -1302.00
# Ep. 2917, Ep.Timesteps 24, Episode Reward: -978.74Ep. 2917, Ep.Timesteps 24, Episode Reward_naive: -1076.00
# Ep. 2918, Ep.Timesteps 24, Episode Reward: -1049.07Ep. 2918, Ep.Timesteps 24, Episode Reward_naive: -1159.00
# Ep. 2919, Ep.Timesteps 24, Episode Reward: -972.94Ep. 2919, Ep.Timesteps 24, Episode Reward_naive: -1078.00
# Ep. 2920, Ep.Timesteps 24, Episode Reward: -925.15Ep. 2920, Ep.Timesteps 24, Episode Reward_naive: -1022.00
# Ep. 2921, Ep.Timesteps 24, Episode Reward: -764.82Ep. 2921, Ep.Timesteps 24, Episode Reward_naive: -838.00
# Ep. 2922, Ep.Timesteps 24, Episode Reward: -919.42Ep. 2922, Ep.Timesteps 24, Episode Reward_naive: -1016.00
# Ep. 2923, Ep.Timesteps 24, Episode Reward: -744.18Ep. 2923, Ep.Timesteps 24, Episode Reward_naive: -816.00
# Ep. 2924, Ep.Timesteps 24, Episode Reward: -799.29Ep. 2924, Ep.Timesteps 24, Episode Reward_naive: -880.00
# Ep. 2925, Ep.Timesteps 24, Episode Reward: -932.30Ep. 2925, Ep.Timesteps 24, Episode Reward_naive: -1040.00
# Ep. 2926, Ep.Timesteps 24, Episode Reward: -986.38Ep. 2926, Ep.Timesteps 24, Episode Reward_naive: -1071.00
# Ep. 2927, Ep.Timesteps 24, Episode Reward: -923.38Ep. 2927, Ep.Timesteps 24, Episode Reward_naive: -1018.00
# Ep. 2928, Ep.Timesteps 24, Episode Reward: -879.32Ep. 2928, Ep.Timesteps 24, Episode Reward_naive: -974.00
# Ep. 2929, Ep.Timesteps 24, Episode Reward: -1058.03Ep. 2929, Ep.Timesteps 24, Episode Reward_naive: -1151.00
# Ep. 2930, Ep.Timesteps 24, Episode Reward: -866.00Ep. 2930, Ep.Timesteps 24, Episode Reward_naive: -944.00
# Ep. 2931, Ep.Timesteps 24, Episode Reward: -810.14Ep. 2931, Ep.Timesteps 24, Episode Reward_naive: -886.00
# Ep. 2932, Ep.Timesteps 24, Episode Reward: -921.01Ep. 2932, Ep.Timesteps 24, Episode Reward_naive: -1011.00
# Ep. 2933, Ep.Timesteps 24, Episode Reward: -1043.15Ep. 2933, Ep.Timesteps 24, Episode Reward_naive: -1148.00

# %%
a = -(np.array(ep_reward_list) - np.array(ep_reward_list_naive)) / ep_reward_list_naive
plt.plot(a)
plt.xlabel('episode number')
plt.ylabel('performance difference')
plt.show()
plt.savefig('final result.png')

# %%
plt.plot(ep_reward_list,color = 'r')
plt.plot(ep_reward_list_naive, color = 'b')
plt.xlabel('episode number')
plt.ylabel('performance score')
plt.show()
plt.savefig('final result 1.png')

# %%
l = np.arange(200)
l = l * 10
b = np.array(a)
b = b.reshape(200,10)
b = np.mean(b,axis = 1)
plt.figure(figsize=(8, 6), dpi=200)
plt.plot(l,b)
plt.xlabel('episode number')
plt.ylabel('performance improvement')
plt.savefig('final result 0.png')

# %%
x = np.array(ep_reward_list)
x = x.reshape(200,10)
x = np.mean(x,axis = 1)

y = np.array(ep_reward_list_naive)
y = y.reshape(200,10)
y = np.mean(y,axis = 1)

plt.figure(figsize=(8, 6), dpi=200)
plt.plot(l,x,color = 'r', label = 'With congestion fee')
plt.plot(l,y, color = 'b', label = 'No congestion fee')
plt.legend()
plt.xlabel('episode number')
plt.ylabel('performance score')

plt.savefig('final result 1.png')
