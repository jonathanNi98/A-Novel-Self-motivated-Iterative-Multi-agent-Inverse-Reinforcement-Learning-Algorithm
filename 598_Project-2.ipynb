# %%
pip install pyvis
# Out:
# Requirement already satisfied: pyvis in /opt/anaconda3/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: networkx>=1.11 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (2.6.3)
# Requirement already satisfied: jsonpickle>=1.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (2.1.0)
# Requirement already satisfied: ipython>=5.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (7.29.0)
# Requirement already satisfied: jinja2>=2.9.6 in /opt/anaconda3/lib/python3.9/site-packages (from pyvis) (2.11.3)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.18.0)
# Requirement already satisfied: pickleshare in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (58.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (3.0.20)
# Requirement already satisfied: pygments in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (2.10.0)
# Requirement already satisfied: backcall in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.1.0)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.3.0->pyvis) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2>=2.9.6->pyvis) (1.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import packages. Run this cell.
import numpy as np
import numpy.random as rn
from numpy.core.fromnumeric import shape
from pyvis import network as net
import torch
import torch.nn as nn
import torch.nn.functional as F
from collections import deque
import torch.optim as optim
from matplotlib import pyplot as plt

# %%
"""
Define the environment
"""

class Gridworld(object):
    """
    Topology MDP.
    """

    def __init__(self, reward_list, discount = 0.95):
        """
        Topology G(9, 16)
        """
        g = net.Network(height='400px', width='50%', heading='')
        self.reward_list = reward_list # Reward list
        self.n_states = 9 # number of states
        # Build the network
        for i in range(self.n_states):
            g.add_node(i)
        g.add_edge(0,1)
        g.add_edge(1,2)
        g.add_edge(2,3)
        g.add_edge(3,0)
        g.add_edge(4,5)
        g.add_edge(5,6)
        g.add_edge(6,7)
        g.add_edge(7,8)
        g.add_edge(4,7)
        g.add_edge(0,4)
        g.add_edge(1,5)
        g.add_edge(2,6)
        g.add_edge(3,7)
        g.add_edge(4,8)
        g.add_edge(5,8)
        g.add_edge(6,8)
        g.add_edge(7,8)
        self.n_arcs = len(g.edges) # num of arcs 16
        self.arcs = g.edges
        self.neighbor_map = g.get_adj_list()
        self.from_set = []
        self.to_set = []
        for j in range(self.n_arcs):
            self.from_set.append(g.edges[j]['from'])
        for j in range(self.n_arcs):
            self.to_set.append(g.edges[j]['to'])
        self.from_set = np.array(self.from_set)
        self.to_set = np.array(self.to_set)
        self.discount = discount

    def state_transition_func(self, state, action):
        """
        Map (current pos and next pos) to the arc
        """
        next = list(self.neighbor_map[state])[action]
        return next

    def reset(max_num):
        """
        New aircraft comes in
        """
        state = np.random.randint(0,max_num,[9,9])
        np.fill_diagonal(state, 0)
        return state

    def canonical_arc(self, cur, next):
        """
        With current and next steps, find the corresponding arc
        """
        # if cur in the from set
        arc_idx = -1
        
        if next in self.from_set[np.where(self.to_set==cur)]:
            arc_idx = np.intersect1d(np.where(self.to_set==cur), np.where(self.from_set==next))
        else:
            arc_idx = np.intersect1d(np.where(self.to_set==next), np.where(self.from_set==cur))
            
        # if self.from_set[self.to_set.index(cur)] == next:
        #     arc_idx = self.to_set.index(cur)
        #     print(arc_idx)
        # elif self.to_set[self.from_set.index(cur)] == next:
        #     arc_idx = self.from_set.index(cur)
        # else:
        #     arc_idx = self.from_set.index(cur)        
        return arc_idx.squeeze()     

    def step(self, state, action, terminal_state):
        arc_idx = 0
        next_state = self.state_transition_func(state, action)
        arc_idx = self.canonical_arc(state, next_state)     
        reward = self.reward_list[arc_idx]
        if state == terminal_state:
            done = True
        else:
            done = False
        return next_state, reward, done


    def value_iteration(self, des):
        """
        Please use value iteration to compute the optimal value function and store it into the vector V with size 64
        For example, V[0] means the optimal value function for state 0.
        """
        V = np.zeros((9,))
        V_old = np.zeros((9,))
        ### BEGIN SOLUTION
        # YOUR CODE HERE
        flag = 1
        while flag:
          for state in range(9):
            if(state == des):
              V[state] = 0
              continue
            list = []

            if state ==0 or state == 1 or state == 2 or state ==3:
                  for action in range(3):  
                    next_state, reward, done = self.step(state, action, terminal_state = des)
                    list.append(self.discount * V_old[next_state] + (reward-1))
                  V[state] = max(list) 
            else:

                  for action in range(4):
                    next_state, reward, done = self.step(state, action, terminal_state = des)
                    list.append(self.discount * V_old[next_state] + (reward-1))
                  V[state] = max(list) 

          # print(V)
          V_change = np.subtract(V, V_old)
          # print(V_old)
          V_change = abs(V_change)
          if np.max(V_change) < 0.1:
            flag = 0

          V_old = np.copy(V)
        ### END SOLUTION
        return V
    
    def value_itr(self):
        V = np.zeros([9,9])
        for i in range(9):
            V[i] = np.array(self.value_iteration(i))
        return V


    def evaluate(self, agent, v):
      evaluate = np.zeros((16,))
      #print('agent',agent,v)
      for a in agent:
        value = v[int(a[1])]
        list = []
        if a[0] == 0 or a[0] == 1 or a[0] == 2 or a[0] == 3 :
            max = -np.inf
            for action in range(3):
              next_state = self.state_transition_func(a[0], action)
              if value[next_state] > max:
                max = value[next_state]
                next_state_0 = next_state
            evaluate[self.canonical_arc(a[0], next_state_0)] += 1
            a[0] = next_state_0
        else:
            max = -np.inf
            for action in range(4):
              next_state = self.state_transition_func(a[0], action)
              if value[next_state] > max:
                next_state_0 = next_state
            evaluate[self.canonical_arc(a[0], next_state)] += 1
            a[0] = next_state_0
      return evaluate,agent

    def score_fun(self,evaluate):
      score = 0
      score = -0.1 * np.sum((self.reward_list) * evaluate) - np.sum(np.maximum(evaluate - np.ones(16),np.zeros(16)))
      return score

    def from_agent_to_config(self,agent):
      config = np.zeros([9,9])
      for a in agent:
        config[a[1],a[0]] += 1
        config = self.clean_config(config)
      return config

    def from_config_to_agent(self,config):
      agent = []
      config = self.clean_config(config)
      config = config.reshape([9,9])
      for i in range(9):
        for j in range(9):
          while config[i,j] != 0:
            agent.append([j,i])
            config[i,j] -= 1
      return agent
    
    def clean_config(self,config):
      if len(config.shape) == 1:
        config = config.reshape([9,9])
      np.fill_diagonal(config, 0)
      return config

    def config_step(self,config):
      V = self.value_itr()
      config = self.clean_config(config)
      agent = self.from_config_to_agent(config)
      evaluate,agent = self.evaluate(agent,V)
      next_config = self.from_agent_to_config(agent)
      next_config = self.clean_config(next_config)
      score = self.score_fun(evaluate)
      return next_config,score

    def add_random_des():
      return

# %%
"""
Some parameters
"""
state_size = 9*9  # state dimension
action_size = 16  # action dimension
fc_units = 256  # number of neurons in one fully connected hidden layer
action_upper_bound = 1  # action space upper bound
action_lower_bound = -1  # action space lower bound


"""
Structure of Actor Network.
"""
class Actor(nn.Module):
    def __init__(self):
        super().__init__()
        self.max_action = action_upper_bound
        self.fc1 = nn.Linear(state_size, fc_units)
        self.fc2 = nn.Linear(fc_units, fc_units)
        self.fc3 = nn.Linear(fc_units, action_size)

    def forward(self, state):
        """
        Build an actor (policy) network that maps states -> actions.
        Args:
            state: torch.Tensor with shape (batch_size, state_size)
        Returns:
            action: torch.Tensor with shape (batch_size, action_size)
        """
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        action = torch.tanh(self.fc3(x)) * self.max_action
        return action


"""
Structure of Critic Network.
"""
class CriticQ(nn.Module):
    def __init__(self):
        """
        Args:
            state_size: state dimension
            action_size: action dimension
            fc_units: number of neurons in one fully connected hidden layer
        """
        super().__init__()
        
        # Q-network 1 architecture
        self.l1 = nn.Linear(state_size + action_size, fc_units)
        self.l2 = nn.Linear(fc_units, fc_units)
        self.l3 = nn.Linear(fc_units, 1)

        # Q-network 2 architecture
        self.l4 = nn.Linear(state_size + action_size, fc_units)
        self.l5 = nn.Linear(fc_units, fc_units)
        self.l6 = nn.Linear(fc_units, 1)

    def forward(self, state, action):
        """
        Build a critic (value) network that maps state-action pairs -> Q-values.
        Args:
            state: torch.Tensor with shape (batch_size, state_size)
            action: torch.Tensor with shape (batch_size, action_size)
        Returns:
            Q_value_1: torch.Tensor with shape (batch_size, 1)
            Q_value_2: torch.Tensor with shape (batch_size, 1)
        """
        state_action = torch.cat([state, action], 1)
        
        x1 = F.relu(self.l1(state_action))
        x1 = F.relu(self.l2(x1))
        Q_value_1 = self.l3(x1)
        
        x2 = F.relu(self.l4(state_action))
        x2 = F.relu(self.l5(x2))
        Q_value_2 = self.l6(x2)
        
        return Q_value_1, Q_value_2

# %%
"""
Implementation of TD3 Algorithm
"""
import random
class TD3:
    def __init__(self):
        self.lr_actor = 1e-2  # learning rate for actor network
        self.lr_critic = 1e-2  # learning rate for critic network
        self.buffer_capacity = 100000  # replay buffer capacity
        self.batch_size = 128  # mini-batch size
        self.tau = 0.02  # soft update parameter
        self.policy_delay = 2  # policy will be updated once every policy_delay times for each update of the Q-networks.
        self.gamma = 0.99  # discount factor
        self.target_noise = 0.2  # standard deviation for smoothing noise added to target policy
        self.noise_clip = 0.5  # limit for absolute value of target policy smoothing noise.
        self.update_every = 200  # number of env interactions that should elapse between updates of Q-networks.
        # Note: Regardless of how long you wait between updates, the ratio of env steps to gradient steps should be 1.
        self.state_size = state_size
        self.action_size = action_size
        self.device = torch.device("cpu")  # or self.device = torch.device("cuda")
        self.action_upper_bound = action_upper_bound  # action space upper bound
        self.action_lower_bound = action_lower_bound  # action space lower bound
        self.create_actor()
        self.create_critic()
        self.act_opt = optim.Adam(self.actor.parameters(), lr=self.lr_actor)
        self.crt_opt = optim.Adam(self.critic.parameters(), lr=self.lr_critic)
        self.replay_memory_buffer = deque(maxlen=self.buffer_capacity)
        
    def create_actor(self):
        self.actor = Actor().to(self.device)
        self.actor_target = Actor().to(self.device)
        self.actor_target.load_state_dict(self.actor.state_dict())

    def create_critic(self):
        self.critic = CriticQ().to(self.device)
        self.critic_target = CriticQ().to(self.device)
        self.critic_target.load_state_dict(self.critic.state_dict())
    
    def add_to_replay_memory(self, state, action, reward, next_state, done):
        """
        Add samples to replay memory
        Args:
            state: current state, a numpy array with shape (state_size,)
            action: current action, a numpy array with shape (action_size,)
            reward: reward obtained
            next_state: next state, a numpy array with shape (state_size,)
            done: True when the current episode ends, False otherwise
        """
        self.replay_memory_buffer.append((state, action, reward, next_state, done))

    def get_random_sample_from_replay_mem(self):
        """
        Random samples from replay memory without replacement
        Returns a self.batch_size length list of unique elements chosen from the replay buffer.
        Returns:
            random_sample: a list with len=self.batch_size,
                           where each element is a tuple (state, action, reward, next_state, done)
        """
        random_sample = random.sample(self.replay_memory_buffer, self.batch_size)
        return random_sample
    
    def soft_update_target(self, local_model, target_model):
        """
        Soft update model parameters.
        θ_target = τ*θ_local + (1 - τ)*θ_target
        Args:
            local_model: PyTorch model (weights will be copied from)
            target_model: PyTorch model (weights will be copied to)
            tau (float): interpolation parameter
        """
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(self.tau*local_param.data + (1.0-self.tau)*target_param.data)

    def train(self, cur_time_step, episode_time_step, state, action, reward, next_state, done):
        """
        Collect samples and update actor network and critic network using mini-batches of experience tuples.
        Args:
            cur_time_step: current time step counting from the beginning, 
                           which is equal to the number of times the agent interacts with the environment
            episode_time_step: the time step counting from the current episode
            state: current state, a numpy array with shape (state_size,)
            action: current action, a numpy array with shape (action_size,)
            reward: reward obtained
            next_state: next state, a numpy array with shape (state_size,)
            done: True when the current episode ends, False otherwise
        """
        self.add_to_replay_memory(state, action, reward, next_state, done)      
        if len(self.replay_memory_buffer) < self.batch_size:
            return
        if cur_time_step % self.update_every != 0:
            return
        
        # Perform self.update_every times of updates of the critic networks and 
        # (self.update_every / policy_delay) times of updates of the actor network
        for it in range(self.update_every): 
            """
            state_batch: torch.Tensor with shape (self.batch_size, state_size), a mini-batch of current states
            action_batch: torch.Tensor with shape (self.batch_size, action_size), a mini-batch of current actions
            reward_batch: torch.Tensor with shape (self.batch_size, 1), a mini-batch of rewards
            next_state_batch: torch.Tensor with shape (self.batch_size, state_size), a mini-batch of next states
            done_list: torch.Tensor with shape (self.batch_size, 1), a mini-batch of 0-1 integers, 
                   where 1 means the episode terminates for that sample;
                         0 means the episode does not terminate for that sample.
            """
            mini_batch = self.get_random_sample_from_replay_mem()
            state_batch = torch.from_numpy(np.vstack([i[0] for i in mini_batch])).float().to(self.device)
            action_batch = torch.from_numpy(np.vstack([i[1] for i in mini_batch])).float().to(self.device)
            reward_batch = torch.from_numpy(np.vstack([i[2] for i in mini_batch])).float().to(self.device)
            next_state_batch = torch.from_numpy(np.vstack([i[3] for i in mini_batch])).float().to(self.device)
            done_list = torch.from_numpy(np.vstack([i[4] for i in mini_batch]).astype(np.uint8)).float().to(self.device)
            
            # Please complete codes for updating the critic networks
            """
            Hints: 
              You may use the above tensors: state_batch, action_batch, reward_batch, next_state_batch, done_list
              You may use self.critic_target and self.actor_target as your target networks
              you may use target policy smoothing techniques with hyperparameters self.target_noise and self.noise_clip
              You may use clipped double Q-learning techniques
              You may update self.critic using the optimizer self.crt_opt and MSE loss function.
              Make sure to consider whether the corresponding episode terminates when calculating target values.
                If the episode terminates, then the next state value should be 0.
            """
            ### BEGIN SOLUTION
            # YOUR CODE HERE
            current_q = self.critic(state_batch,action_batch)
            next_action_batch = self.actor_target(next_state_batch) + torch.clamp(torch.normal(0,0.2,action_batch.shape),-self.noise_clip,self.noise_clip)
            target_q1 = reward_batch + torch.mul(torch.mul(self.critic_target(next_state_batch,next_action_batch)[0].detach(),self.gamma),1-done_list)
            target_q2 = reward_batch + torch.mul(torch.mul(self.critic_target(next_state_batch,next_action_batch)[1].detach(),self.gamma),1-done_list)
            
            y = torch.min(target_q1,target_q2)
            loss = ((torch.sum((y - current_q[0])**2) + torch.sum((y - current_q[1])**2))).mean()
            self.crt_opt.zero_grad()
            loss.backward()
            self.crt_opt.step()
            ### END SOLUTION
           
            # Train Actor
            # Delayed policy updates
            # Update self.actor once every policy_delay times for each update of self.critic
            if it % self.policy_delay == 0:
                
                # Please complete codes for updating of the actor network
                """
                Hint: 
                  You may update self.actor using the optimizer self.act_opt and recall the loss function for DDPG training
                """
                ### BEGIN SOLUTION
                # YOUR CODE HERE
                actor = self.actor(state_batch)
                q1,q2 = self.critic(state_batch,actor)
                loss = -sum(q1+q2)
                self.act_opt.zero_grad()
                loss.backward()
                self.act_opt.step()
                ### END SOLUTION
                
                # Soft update target models
                self.soft_update_target(self.critic, self.critic_target)
                self.soft_update_target(self.actor, self.actor_target)
            
    
    def policy(self, state):
        """
        Select action based on the actor network.
        Args:
            state: a numpy array with shape (state_size,)
        Returns:
            actions: a numpy array with shape (action_size,)
        """
        state = torch.from_numpy(state).float().unsqueeze(0).to(self.device)
        self.actor.eval()
        with torch.no_grad():
            actions = np.squeeze(self.actor(state).cpu().data.numpy())
        self.actor.train()
        return actions

# %%
def generate_config(num_max):
        state = np.random.randint(0,num_max,[9,9])
        np.fill_diagonal(state, 0)
        return state

# %%
a = np.zeros([9,9])
a = generate_config(5)
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

timesteps_count = 0  # Counting the time steps
max_steps = 24  # Maximum time steps for one episode
ep_reward_list = []
ep_reward_list_naive = []
avg_reward = -9999
agent = TD3()

for ep in range(2000):
    config = generate_config(3)
    config = config.flatten()
    episodic_reward = 0
    timestep_for_cur_episode = 0
    episodic_reward_naive = 0
    score = []

    for st in range(max_steps):
        a = np.copy(config)
        # Select action according to policy
        action = agent.policy(config.flatten())
        env = Gridworld(action)
        # Recieve state and reward from environment.
        next_config, reward = env.config_step(config)
        next_config = next_config.flatten()
        done = 0
        episodic_reward += reward
        if next_config.any() == 0:
          done = 1
        # Send the experience to the agent and train the agent
        agent.train(timesteps_count, timestep_for_cur_episode, config, action, reward, next_config, done)
        timestep_for_cur_episode += 1
        timesteps_count += 1
        
        #comparison
        action_naive = -np.zeros(16)
        env = Gridworld(action_naive)
        next_config_naive, reward_naive = env.config_step(a)
        next_config_naive = next_config_naive.flatten()
        episodic_reward_naive += reward_naive
        
        # End this episode when `done` is True
        if done:
            break
        config = next_config

    ep_reward_list.append(episodic_reward)
    ep_reward_list_naive.append(episodic_reward_naive)
    print('Ep. {}, Ep.Timesteps {}, Episode Reward: {:.2f}'.format(ep + 1, timestep_for_cur_episode, episodic_reward), end='')
    print('Ep. {}, Ep.Timesteps {}, Episode Reward_naive: {:.2f}'.format(ep + 1, timestep_for_cur_episode, episodic_reward_naive), end='')
    
    if len(ep_reward_list) == 50:
        # Mean of last 50 episodes
        avg_reward = sum(ep_reward_list) / 50
        print(', Moving Average Reward: {:.2f}'.format(avg_reward))
    else:
        print('')
print('Average reward over 50 episodes: ', avg_reward)
plt.plot(ep_reward_list,color = 'r')
plt.plot(ep_reward_list_naive, color = 'b')
print(np.mean(ep_reward_list),np.mean(ep_reward_list_naive))
# Out:
# Ep. 1, Ep.Timesteps 24, Episode Reward: -750.51Ep. 1, Ep.Timesteps 24, Episode Reward_naive: -736.00
# Ep. 2, Ep.Timesteps 24, Episode Reward: -967.08Ep. 2, Ep.Timesteps 24, Episode Reward_naive: -951.00
# Ep. 3, Ep.Timesteps 24, Episode Reward: -893.66Ep. 3, Ep.Timesteps 24, Episode Reward_naive: -870.00
# Ep. 4, Ep.Timesteps 24, Episode Reward: -1027.11Ep. 4, Ep.Timesteps 24, Episode Reward_naive: -1005.00
# Ep. 5, Ep.Timesteps 24, Episode Reward: -1045.26Ep. 5, Ep.Timesteps 24, Episode Reward_naive: -1030.00
# Ep. 6, Ep.Timesteps 24, Episode Reward: -1006.20Ep. 6, Ep.Timesteps 24, Episode Reward_naive: -984.00
# Ep. 7, Ep.Timesteps 24, Episode Reward: -1215.32Ep. 7, Ep.Timesteps 24, Episode Reward_naive: -1186.00
# Ep. 8, Ep.Timesteps 24, Episode Reward: -1032.12Ep. 8, Ep.Timesteps 24, Episode Reward_naive: -1003.00
# Ep. 9, Ep.Timesteps 24, Episode Reward: -1029.20Ep. 9, Ep.Timesteps 24, Episode Reward_naive: -969.00
# Ep. 10, Ep.Timesteps 24, Episode Reward: -1226.34Ep. 10, Ep.Timesteps 24, Episode Reward_naive: -1064.00
# Ep. 11, Ep.Timesteps 24, Episode Reward: -1131.82Ep. 11, Ep.Timesteps 24, Episode Reward_naive: -958.00
# Ep. 12, Ep.Timesteps 24, Episode Reward: -1130.14Ep. 12, Ep.Timesteps 24, Episode Reward_naive: -946.00
# Ep. 13, Ep.Timesteps 24, Episode Reward: -1347.93Ep. 13, Ep.Timesteps 24, Episode Reward_naive: -1146.00
# Ep. 14, Ep.Timesteps 24, Episode Reward: -1030.97Ep. 14, Ep.Timesteps 24, Episode Reward_naive: -856.00
# Ep. 15, Ep.Timesteps 24, Episode Reward: -1215.38Ep. 15, Ep.Timesteps 24, Episode Reward_naive: -1044.00
# Ep. 16, Ep.Timesteps 24, Episode Reward: -1018.84Ep. 16, Ep.Timesteps 24, Episode Reward_naive: -843.00
# Ep. 17, Ep.Timesteps 24, Episode Reward: -1028.58Ep. 17, Ep.Timesteps 24, Episode Reward_naive: -944.00
# Ep. 18, Ep.Timesteps 24, Episode Reward: -857.00Ep. 18, Ep.Timesteps 24, Episode Reward_naive: -839.00
# Ep. 19, Ep.Timesteps 24, Episode Reward: -1070.58Ep. 19, Ep.Timesteps 24, Episode Reward_naive: -1047.00
# Ep. 20, Ep.Timesteps 24, Episode Reward: -1041.80Ep. 20, Ep.Timesteps 24, Episode Reward_naive: -1011.00
# Ep. 21, Ep.Timesteps 24, Episode Reward: -1120.09Ep. 21, Ep.Timesteps 24, Episode Reward_naive: -1089.00
# Ep. 22, Ep.Timesteps 24, Episode Reward: -1174.35Ep. 22, Ep.Timesteps 24, Episode Reward_naive: -1138.00
# Ep. 23, Ep.Timesteps 24, Episode Reward: -1180.45Ep. 23, Ep.Timesteps 24, Episode Reward_naive: -1152.00
# Ep. 24, Ep.Timesteps 24, Episode Reward: -1237.64Ep. 24, Ep.Timesteps 24, Episode Reward_naive: -1209.00
# Ep. 25, Ep.Timesteps 24, Episode Reward: -1095.90Ep. 25, Ep.Timesteps 24, Episode Reward_naive: -1069.00
# Ep. 26, Ep.Timesteps 24, Episode Reward: -711.02Ep. 26, Ep.Timesteps 24, Episode Reward_naive: -760.00
# Ep. 27, Ep.Timesteps 24, Episode Reward: -837.82Ep. 27, Ep.Timesteps 24, Episode Reward_naive: -807.00
# Ep. 28, Ep.Timesteps 24, Episode Reward: -758.48Ep. 28, Ep.Timesteps 24, Episode Reward_naive: -754.00
# Ep. 29, Ep.Timesteps 24, Episode Reward: -777.39Ep. 29, Ep.Timesteps 24, Episode Reward_naive: -814.00
# Ep. 30, Ep.Timesteps 24, Episode Reward: -851.75Ep. 30, Ep.Timesteps 24, Episode Reward_naive: -886.00
# Ep. 31, Ep.Timesteps 24, Episode Reward: -991.52Ep. 31, Ep.Timesteps 24, Episode Reward_naive: -1075.00
# Ep. 32, Ep.Timesteps 24, Episode Reward: -979.44Ep. 32, Ep.Timesteps 24, Episode Reward_naive: -958.00
# Ep. 33, Ep.Timesteps 24, Episode Reward: -838.68Ep. 33, Ep.Timesteps 24, Episode Reward_naive: -839.00
# Ep. 34, Ep.Timesteps 24, Episode Reward: -1143.59Ep. 34, Ep.Timesteps 24, Episode Reward_naive: -1158.00
# Ep. 35, Ep.Timesteps 24, Episode Reward: -821.07Ep. 35, Ep.Timesteps 24, Episode Reward_naive: -823.00
# Ep. 36, Ep.Timesteps 24, Episode Reward: -806.42Ep. 36, Ep.Timesteps 24, Episode Reward_naive: -818.00
# Ep. 37, Ep.Timesteps 24, Episode Reward: -666.18Ep. 37, Ep.Timesteps 24, Episode Reward_naive: -682.00
# Ep. 38, Ep.Timesteps 24, Episode Reward: -898.82Ep. 38, Ep.Timesteps 24, Episode Reward_naive: -898.00
# Ep. 39, Ep.Timesteps 24, Episode Reward: -713.28Ep. 39, Ep.Timesteps 24, Episode Reward_naive: -708.00
# Ep. 40, Ep.Timesteps 24, Episode Reward: -1075.52Ep. 40, Ep.Timesteps 24, Episode Reward_naive: -1090.00
# Ep. 41, Ep.Timesteps 24, Episode Reward: -829.83Ep. 41, Ep.Timesteps 24, Episode Reward_naive: -849.00
# Ep. 42, Ep.Timesteps 24, Episode Reward: -759.38Ep. 42, Ep.Timesteps 24, Episode Reward_naive: -767.00
# Ep. 43, Ep.Timesteps 24, Episode Reward: -1020.84Ep. 43, Ep.Timesteps 24, Episode Reward_naive: -1034.00
# Ep. 44, Ep.Timesteps 24, Episode Reward: -838.10Ep. 44, Ep.Timesteps 24, Episode Reward_naive: -849.00
# Ep. 45, Ep.Timesteps 24, Episode Reward: -983.44Ep. 45, Ep.Timesteps 24, Episode Reward_naive: -996.00
# Ep. 46, Ep.Timesteps 24, Episode Reward: -1061.35Ep. 46, Ep.Timesteps 24, Episode Reward_naive: -1084.00
# Ep. 47, Ep.Timesteps 24, Episode Reward: -888.42Ep. 47, Ep.Timesteps 24, Episode Reward_naive: -892.00
# Ep. 48, Ep.Timesteps 24, Episode Reward: -982.39Ep. 48, Ep.Timesteps 24, Episode Reward_naive: -993.00
# Ep. 49, Ep.Timesteps 24, Episode Reward: -932.28Ep. 49, Ep.Timesteps 24, Episode Reward_naive: -946.00
# Ep. 50, Ep.Timesteps 24, Episode Reward: -854.24Ep. 50, Ep.Timesteps 24, Episode Reward_naive: -863.00, Moving Average Reward: -977.91
# Ep. 51, Ep.Timesteps 24, Episode Reward: -897.33Ep. 51, Ep.Timesteps 24, Episode Reward_naive: -902.00
# Ep. 52, Ep.Timesteps 24, Episode Reward: -715.19Ep. 52, Ep.Timesteps 24, Episode Reward_naive: -718.00
# Ep. 53, Ep.Timesteps 24, Episode Reward: -792.08Ep. 53, Ep.Timesteps 24, Episode Reward_naive: -797.00
# Ep. 54, Ep.Timesteps 24, Episode Reward: -890.33Ep. 54, Ep.Timesteps 24, Episode Reward_naive: -895.00
# Ep. 55, Ep.Timesteps 24, Episode Reward: -750.07Ep. 55, Ep.Timesteps 24, Episode Reward_naive: -751.00
# Ep. 56, Ep.Timesteps 24, Episode Reward: -997.12Ep. 56, Ep.Timesteps 24, Episode Reward_naive: -977.00
# Ep. 57, Ep.Timesteps 24, Episode Reward: -854.33Ep. 57, Ep.Timesteps 24, Episode Reward_naive: -860.00
# Ep. 58, Ep.Timesteps 24, Episode Reward: -685.44Ep. 58, Ep.Timesteps 24, Episode Reward_naive: -680.00
# Ep. 59, Ep.Timesteps 24, Episode Reward: -893.16Ep. 59, Ep.Timesteps 24, Episode Reward_naive: -904.00
# Ep. 60, Ep.Timesteps 24, Episode Reward: -831.76Ep. 60, Ep.Timesteps 24, Episode Reward_naive: -851.00
# Ep. 61, Ep.Timesteps 24, Episode Reward: -724.01Ep. 61, Ep.Timesteps 24, Episode Reward_naive: -731.00
# Ep. 62, Ep.Timesteps 24, Episode Reward: -727.24Ep. 62, Ep.Timesteps 24, Episode Reward_naive: -742.00
# Ep. 63, Ep.Timesteps 24, Episode Reward: -937.56Ep. 63, Ep.Timesteps 24, Episode Reward_naive: -958.00
# Ep. 64, Ep.Timesteps 24, Episode Reward: -888.05Ep. 64, Ep.Timesteps 24, Episode Reward_naive: -906.00
# Ep. 65, Ep.Timesteps 24, Episode Reward: -922.60Ep. 65, Ep.Timesteps 24, Episode Reward_naive: -947.00
# Ep. 66, Ep.Timesteps 24, Episode Reward: -844.28Ep. 66, Ep.Timesteps 24, Episode Reward_naive: -867.00
# Ep. 67, Ep.Timesteps 24, Episode Reward: -808.16Ep. 67, Ep.Timesteps 24, Episode Reward_naive: -838.00
# Ep. 68, Ep.Timesteps 24, Episode Reward: -870.83Ep. 68, Ep.Timesteps 24, Episode Reward_naive: -943.00
# Ep. 69, Ep.Timesteps 24, Episode Reward: -942.96Ep. 69, Ep.Timesteps 24, Episode Reward_naive: -1015.00
# Ep. 70, Ep.Timesteps 24, Episode Reward: -694.41Ep. 70, Ep.Timesteps 24, Episode Reward_naive: -748.00
# Ep. 71, Ep.Timesteps 24, Episode Reward: -620.49Ep. 71, Ep.Timesteps 24, Episode Reward_naive: -667.00
# Ep. 72, Ep.Timesteps 24, Episode Reward: -826.29Ep. 72, Ep.Timesteps 24, Episode Reward_naive: -892.00
# Ep. 73, Ep.Timesteps 24, Episode Reward: -775.15Ep. 73, Ep.Timesteps 24, Episode Reward_naive: -834.00
# Ep. 74, Ep.Timesteps 24, Episode Reward: -790.45Ep. 74, Ep.Timesteps 24, Episode Reward_naive: -848.00
# Ep. 75, Ep.Timesteps 24, Episode Reward: -1135.05Ep. 75, Ep.Timesteps 24, Episode Reward_naive: -1226.00
# Ep. 76, Ep.Timesteps 24, Episode Reward: -627.42Ep. 76, Ep.Timesteps 24, Episode Reward_naive: -672.00
# Ep. 77, Ep.Timesteps 24, Episode Reward: -868.81Ep. 77, Ep.Timesteps 24, Episode Reward_naive: -847.00
# Ep. 78, Ep.Timesteps 24, Episode Reward: -905.81Ep. 78, Ep.Timesteps 24, Episode Reward_naive: -862.00
# Ep. 79, Ep.Timesteps 24, Episode Reward: -986.14Ep. 79, Ep.Timesteps 24, Episode Reward_naive: -929.00
# Ep. 80, Ep.Timesteps 24, Episode Reward: -1165.84Ep. 80, Ep.Timesteps 24, Episode Reward_naive: -1134.00
# Ep. 81, Ep.Timesteps 24, Episode Reward: -773.67Ep. 81, Ep.Timesteps 24, Episode Reward_naive: -791.00
# Ep. 82, Ep.Timesteps 24, Episode Reward: -1070.74Ep. 82, Ep.Timesteps 24, Episode Reward_naive: -1028.00
# Ep. 83, Ep.Timesteps 24, Episode Reward: -1301.33Ep. 83, Ep.Timesteps 24, Episode Reward_naive: -1280.00
# Ep. 84, Ep.Timesteps 24, Episode Reward: -1005.82Ep. 84, Ep.Timesteps 24, Episode Reward_naive: -967.00
# Ep. 85, Ep.Timesteps 24, Episode Reward: -810.41Ep. 85, Ep.Timesteps 24, Episode Reward_naive: -789.00
# Ep. 86, Ep.Timesteps 24, Episode Reward: -850.09Ep. 86, Ep.Timesteps 24, Episode Reward_naive: -815.00
# Ep. 87, Ep.Timesteps 24, Episode Reward: -834.19Ep. 87, Ep.Timesteps 24, Episode Reward_naive: -780.00
# Ep. 88, Ep.Timesteps 24, Episode Reward: -859.69Ep. 88, Ep.Timesteps 24, Episode Reward_naive: -823.00
# Ep. 89, Ep.Timesteps 24, Episode Reward: -805.38Ep. 89, Ep.Timesteps 24, Episode Reward_naive: -806.00
# Ep. 90, Ep.Timesteps 24, Episode Reward: -1026.99Ep. 90, Ep.Timesteps 24, Episode Reward_naive: -973.00
# Ep. 91, Ep.Timesteps 24, Episode Reward: -913.83Ep. 91, Ep.Timesteps 24, Episode Reward_naive: -863.00
# Ep. 92, Ep.Timesteps 24, Episode Reward: -1084.81Ep. 92, Ep.Timesteps 24, Episode Reward_naive: -1020.00
# Ep. 93, Ep.Timesteps 24, Episode Reward: -1183.35Ep. 93, Ep.Timesteps 24, Episode Reward_naive: -1093.00
# Ep. 94, Ep.Timesteps 24, Episode Reward: -1099.56Ep. 94, Ep.Timesteps 24, Episode Reward_naive: -1016.00
# Ep. 95, Ep.Timesteps 24, Episode Reward: -1132.49Ep. 95, Ep.Timesteps 24, Episode Reward_naive: -1025.00
# Ep. 96, Ep.Timesteps 24, Episode Reward: -1063.34Ep. 96, Ep.Timesteps 24, Episode Reward_naive: -992.00
# Ep. 97, Ep.Timesteps 24, Episode Reward: -1033.78Ep. 97, Ep.Timesteps 24, Episode Reward_naive: -956.00
# Ep. 98, Ep.Timesteps 24, Episode Reward: -933.35Ep. 98, Ep.Timesteps 24, Episode Reward_naive: -845.00
# Ep. 99, Ep.Timesteps 24, Episode Reward: -1184.35Ep. 99, Ep.Timesteps 24, Episode Reward_naive: -1073.00
# Ep. 100, Ep.Timesteps 24, Episode Reward: -914.16Ep. 100, Ep.Timesteps 24, Episode Reward_naive: -798.00
# Ep. 101, Ep.Timesteps 24, Episode Reward: -999.36Ep. 101, Ep.Timesteps 24, Episode Reward_naive: -989.00
# Ep. 102, Ep.Timesteps 24, Episode Reward: -1102.44Ep. 102, Ep.Timesteps 24, Episode Reward_naive: -1073.00
# Ep. 103, Ep.Timesteps 24, Episode Reward: -1110.44Ep. 103, Ep.Timesteps 24, Episode Reward_naive: -1100.00
# Ep. 104, Ep.Timesteps 24, Episode Reward: -904.86Ep. 104, Ep.Timesteps 24, Episode Reward_naive: -875.00
# Ep. 105, Ep.Timesteps 24, Episode Reward: -789.12Ep. 105, Ep.Timesteps 24, Episode Reward_naive: -790.00
# Ep. 106, Ep.Timesteps 24, Episode Reward: -920.70Ep. 106, Ep.Timesteps 24, Episode Reward_naive: -928.00
# Ep. 107, Ep.Timesteps 24, Episode Reward: -984.83Ep. 107, Ep.Timesteps 24, Episode Reward_naive: -957.00
# Ep. 108, Ep.Timesteps 24, Episode Reward: -934.18Ep. 108, Ep.Timesteps 24, Episode Reward_naive: -923.00
# Ep. 109, Ep.Timesteps 24, Episode Reward: -962.34Ep. 109, Ep.Timesteps 24, Episode Reward_naive: -989.00
# Ep. 110, Ep.Timesteps 24, Episode Reward: -903.06Ep. 110, Ep.Timesteps 24, Episode Reward_naive: -967.00
# Ep. 111, Ep.Timesteps 24, Episode Reward: -838.19Ep. 111, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 112, Ep.Timesteps 24, Episode Reward: -652.21Ep. 112, Ep.Timesteps 24, Episode Reward_naive: -694.00
# Ep. 113, Ep.Timesteps 24, Episode Reward: -969.78Ep. 113, Ep.Timesteps 24, Episode Reward_naive: -1036.00
# Ep. 114, Ep.Timesteps 24, Episode Reward: -582.91Ep. 114, Ep.Timesteps 24, Episode Reward_naive: -624.00
# Ep. 115, Ep.Timesteps 24, Episode Reward: -791.49Ep. 115, Ep.Timesteps 24, Episode Reward_naive: -842.00
# Ep. 116, Ep.Timesteps 24, Episode Reward: -837.43Ep. 116, Ep.Timesteps 24, Episode Reward_naive: -899.00
# Ep. 117, Ep.Timesteps 24, Episode Reward: -975.79Ep. 117, Ep.Timesteps 24, Episode Reward_naive: -1020.00
# Ep. 118, Ep.Timesteps 24, Episode Reward: -821.70Ep. 118, Ep.Timesteps 24, Episode Reward_naive: -830.00
# Ep. 119, Ep.Timesteps 24, Episode Reward: -851.80Ep. 119, Ep.Timesteps 24, Episode Reward_naive: -854.00
# Ep. 120, Ep.Timesteps 24, Episode Reward: -999.23Ep. 120, Ep.Timesteps 24, Episode Reward_naive: -1013.00
# Ep. 121, Ep.Timesteps 24, Episode Reward: -1171.88Ep. 121, Ep.Timesteps 24, Episode Reward_naive: -1204.00
# Ep. 122, Ep.Timesteps 24, Episode Reward: -953.42Ep. 122, Ep.Timesteps 24, Episode Reward_naive: -966.00
# Ep. 123, Ep.Timesteps 24, Episode Reward: -948.29Ep. 123, Ep.Timesteps 24, Episode Reward_naive: -962.00
# Ep. 124, Ep.Timesteps 24, Episode Reward: -1006.75Ep. 124, Ep.Timesteps 24, Episode Reward_naive: -1023.00
# Ep. 125, Ep.Timesteps 24, Episode Reward: -921.60Ep. 125, Ep.Timesteps 24, Episode Reward_naive: -938.00
# Ep. 126, Ep.Timesteps 24, Episode Reward: -890.03Ep. 126, Ep.Timesteps 24, Episode Reward_naive: -914.00
# Ep. 127, Ep.Timesteps 24, Episode Reward: -1187.77Ep. 127, Ep.Timesteps 24, Episode Reward_naive: -1233.00
# Ep. 128, Ep.Timesteps 24, Episode Reward: -1023.02Ep. 128, Ep.Timesteps 24, Episode Reward_naive: -1056.00
# Ep. 129, Ep.Timesteps 24, Episode Reward: -1088.86Ep. 129, Ep.Timesteps 24, Episode Reward_naive: -1115.00
# Ep. 130, Ep.Timesteps 24, Episode Reward: -899.30Ep. 130, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 131, Ep.Timesteps 24, Episode Reward: -1093.79Ep. 131, Ep.Timesteps 24, Episode Reward_naive: -1129.00
# Ep. 132, Ep.Timesteps 24, Episode Reward: -774.29Ep. 132, Ep.Timesteps 24, Episode Reward_naive: -791.00
# Ep. 133, Ep.Timesteps 24, Episode Reward: -1070.32Ep. 133, Ep.Timesteps 24, Episode Reward_naive: -1099.00
# Ep. 134, Ep.Timesteps 24, Episode Reward: -931.26Ep. 134, Ep.Timesteps 24, Episode Reward_naive: -971.00
# Ep. 135, Ep.Timesteps 24, Episode Reward: -978.25Ep. 135, Ep.Timesteps 24, Episode Reward_naive: -1017.00
# Ep. 136, Ep.Timesteps 24, Episode Reward: -1042.96Ep. 136, Ep.Timesteps 24, Episode Reward_naive: -1095.00
# Ep. 137, Ep.Timesteps 24, Episode Reward: -722.30Ep. 137, Ep.Timesteps 24, Episode Reward_naive: -748.00
# Ep. 138, Ep.Timesteps 24, Episode Reward: -789.54Ep. 138, Ep.Timesteps 24, Episode Reward_naive: -822.00
# Ep. 139, Ep.Timesteps 24, Episode Reward: -776.97Ep. 139, Ep.Timesteps 24, Episode Reward_naive: -807.00
# Ep. 140, Ep.Timesteps 24, Episode Reward: -999.15Ep. 140, Ep.Timesteps 24, Episode Reward_naive: -1042.00
# Ep. 141, Ep.Timesteps 24, Episode Reward: -975.20Ep. 141, Ep.Timesteps 24, Episode Reward_naive: -1023.00
# Ep. 142, Ep.Timesteps 24, Episode Reward: -919.08Ep. 142, Ep.Timesteps 24, Episode Reward_naive: -966.00
# Ep. 143, Ep.Timesteps 24, Episode Reward: -991.45Ep. 143, Ep.Timesteps 24, Episode Reward_naive: -1018.00
# Ep. 144, Ep.Timesteps 24, Episode Reward: -880.74Ep. 144, Ep.Timesteps 24, Episode Reward_naive: -939.00
# Ep. 145, Ep.Timesteps 24, Episode Reward: -826.67Ep. 145, Ep.Timesteps 24, Episode Reward_naive: -865.00
# Ep. 146, Ep.Timesteps 24, Episode Reward: -986.56Ep. 146, Ep.Timesteps 24, Episode Reward_naive: -1053.00
# Ep. 147, Ep.Timesteps 24, Episode Reward: -870.25Ep. 147, Ep.Timesteps 24, Episode Reward_naive: -890.00
# Ep. 148, Ep.Timesteps 24, Episode Reward: -868.08Ep. 148, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 149, Ep.Timesteps 24, Episode Reward: -934.00Ep. 149, Ep.Timesteps 24, Episode Reward_naive: -995.00
# Ep. 150, Ep.Timesteps 24, Episode Reward: -863.47Ep. 150, Ep.Timesteps 24, Episode Reward_naive: -916.00
# Ep. 151, Ep.Timesteps 24, Episode Reward: -910.90Ep. 151, Ep.Timesteps 24, Episode Reward_naive: -950.00
# Ep. 152, Ep.Timesteps 24, Episode Reward: -781.99Ep. 152, Ep.Timesteps 24, Episode Reward_naive: -815.00
# Ep. 153, Ep.Timesteps 24, Episode Reward: -911.22Ep. 153, Ep.Timesteps 24, Episode Reward_naive: -910.00
# Ep. 154, Ep.Timesteps 24, Episode Reward: -861.03Ep. 154, Ep.Timesteps 24, Episode Reward_naive: -906.00
# Ep. 155, Ep.Timesteps 24, Episode Reward: -869.85Ep. 155, Ep.Timesteps 24, Episode Reward_naive: -918.00
# Ep. 156, Ep.Timesteps 24, Episode Reward: -894.59Ep. 156, Ep.Timesteps 24, Episode Reward_naive: -881.00
# Ep. 157, Ep.Timesteps 24, Episode Reward: -917.90Ep. 157, Ep.Timesteps 24, Episode Reward_naive: -970.00
# Ep. 158, Ep.Timesteps 24, Episode Reward: -752.91Ep. 158, Ep.Timesteps 24, Episode Reward_naive: -794.00
# Ep. 159, Ep.Timesteps 24, Episode Reward: -1026.64Ep. 159, Ep.Timesteps 24, Episode Reward_naive: -1011.00
# Ep. 160, Ep.Timesteps 24, Episode Reward: -912.78Ep. 160, Ep.Timesteps 24, Episode Reward_naive: -922.00
# Ep. 161, Ep.Timesteps 24, Episode Reward: -915.56Ep. 161, Ep.Timesteps 24, Episode Reward_naive: -879.00
# Ep. 162, Ep.Timesteps 24, Episode Reward: -942.05Ep. 162, Ep.Timesteps 24, Episode Reward_naive: -960.00
# Ep. 163, Ep.Timesteps 24, Episode Reward: -900.36Ep. 163, Ep.Timesteps 24, Episode Reward_naive: -863.00
# Ep. 164, Ep.Timesteps 24, Episode Reward: -902.73Ep. 164, Ep.Timesteps 24, Episode Reward_naive: -920.00
# Ep. 165, Ep.Timesteps 24, Episode Reward: -657.95Ep. 165, Ep.Timesteps 24, Episode Reward_naive: -663.00
# Ep. 166, Ep.Timesteps 24, Episode Reward: -877.42Ep. 166, Ep.Timesteps 24, Episode Reward_naive: -899.00
# Ep. 167, Ep.Timesteps 24, Episode Reward: -1126.75Ep. 167, Ep.Timesteps 24, Episode Reward_naive: -1151.00
# Ep. 168, Ep.Timesteps 24, Episode Reward: -886.40Ep. 168, Ep.Timesteps 24, Episode Reward_naive: -892.00
# Ep. 169, Ep.Timesteps 24, Episode Reward: -890.86Ep. 169, Ep.Timesteps 24, Episode Reward_naive: -895.00
# Ep. 170, Ep.Timesteps 24, Episode Reward: -792.82Ep. 170, Ep.Timesteps 24, Episode Reward_naive: -800.00
# Ep. 171, Ep.Timesteps 24, Episode Reward: -737.71Ep. 171, Ep.Timesteps 24, Episode Reward_naive: -740.00
# Ep. 172, Ep.Timesteps 24, Episode Reward: -783.15Ep. 172, Ep.Timesteps 24, Episode Reward_naive: -791.00
# Ep. 173, Ep.Timesteps 24, Episode Reward: -968.57Ep. 173, Ep.Timesteps 24, Episode Reward_naive: -983.00
# Ep. 174, Ep.Timesteps 24, Episode Reward: -777.03Ep. 174, Ep.Timesteps 24, Episode Reward_naive: -778.00
# Ep. 175, Ep.Timesteps 24, Episode Reward: -825.41Ep. 175, Ep.Timesteps 24, Episode Reward_naive: -838.00
# Ep. 176, Ep.Timesteps 24, Episode Reward: -724.75Ep. 176, Ep.Timesteps 24, Episode Reward_naive: -724.00
# Ep. 177, Ep.Timesteps 24, Episode Reward: -1100.90Ep. 177, Ep.Timesteps 24, Episode Reward_naive: -1127.00
# Ep. 178, Ep.Timesteps 24, Episode Reward: -882.88Ep. 178, Ep.Timesteps 24, Episode Reward_naive: -889.00
# Ep. 179, Ep.Timesteps 24, Episode Reward: -880.31Ep. 179, Ep.Timesteps 24, Episode Reward_naive: -890.00
# Ep. 180, Ep.Timesteps 24, Episode Reward: -897.20Ep. 180, Ep.Timesteps 24, Episode Reward_naive: -907.00
# Ep. 181, Ep.Timesteps 24, Episode Reward: -975.02Ep. 181, Ep.Timesteps 24, Episode Reward_naive: -968.00
# Ep. 182, Ep.Timesteps 24, Episode Reward: -876.55Ep. 182, Ep.Timesteps 24, Episode Reward_naive: -887.00
# Ep. 183, Ep.Timesteps 24, Episode Reward: -864.63Ep. 183, Ep.Timesteps 24, Episode Reward_naive: -881.00
# Ep. 184, Ep.Timesteps 24, Episode Reward: -925.13Ep. 184, Ep.Timesteps 24, Episode Reward_naive: -947.00
# Ep. 185, Ep.Timesteps 24, Episode Reward: -796.02Ep. 185, Ep.Timesteps 24, Episode Reward_naive: -830.00
# Ep. 186, Ep.Timesteps 24, Episode Reward: -826.21Ep. 186, Ep.Timesteps 24, Episode Reward_naive: -848.00
# Ep. 187, Ep.Timesteps 24, Episode Reward: -930.15Ep. 187, Ep.Timesteps 24, Episode Reward_naive: -969.00
# Ep. 188, Ep.Timesteps 24, Episode Reward: -951.79Ep. 188, Ep.Timesteps 24, Episode Reward_naive: -987.00
# Ep. 189, Ep.Timesteps 24, Episode Reward: -966.61Ep. 189, Ep.Timesteps 24, Episode Reward_naive: -999.00
# Ep. 190, Ep.Timesteps 24, Episode Reward: -897.50Ep. 190, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 191, Ep.Timesteps 24, Episode Reward: -816.60Ep. 191, Ep.Timesteps 24, Episode Reward_naive: -839.00
# Ep. 192, Ep.Timesteps 24, Episode Reward: -951.65Ep. 192, Ep.Timesteps 24, Episode Reward_naive: -1008.00
# Ep. 193, Ep.Timesteps 24, Episode Reward: -1059.14Ep. 193, Ep.Timesteps 24, Episode Reward_naive: -1149.00
# Ep. 194, Ep.Timesteps 24, Episode Reward: -1131.04Ep. 194, Ep.Timesteps 24, Episode Reward_naive: -1225.00
# Ep. 195, Ep.Timesteps 24, Episode Reward: -761.96Ep. 195, Ep.Timesteps 24, Episode Reward_naive: -825.00
# Ep. 196, Ep.Timesteps 24, Episode Reward: -1041.76Ep. 196, Ep.Timesteps 24, Episode Reward_naive: -1132.00
# Ep. 197, Ep.Timesteps 24, Episode Reward: -753.20Ep. 197, Ep.Timesteps 24, Episode Reward_naive: -818.00
# Ep. 198, Ep.Timesteps 24, Episode Reward: -985.43Ep. 198, Ep.Timesteps 24, Episode Reward_naive: -1068.00
# Ep. 199, Ep.Timesteps 24, Episode Reward: -941.88Ep. 199, Ep.Timesteps 24, Episode Reward_naive: -1020.00
# Ep. 200, Ep.Timesteps 24, Episode Reward: -833.57Ep. 200, Ep.Timesteps 24, Episode Reward_naive: -900.00
# Ep. 201, Ep.Timesteps 24, Episode Reward: -669.34Ep. 201, Ep.Timesteps 24, Episode Reward_naive: -725.00
# Ep. 202, Ep.Timesteps 24, Episode Reward: -950.75Ep. 202, Ep.Timesteps 24, Episode Reward_naive: -1038.00
# Ep. 203, Ep.Timesteps 24, Episode Reward: -918.49Ep. 203, Ep.Timesteps 24, Episode Reward_naive: -1002.00
# Ep. 204, Ep.Timesteps 24, Episode Reward: -1079.50Ep. 204, Ep.Timesteps 24, Episode Reward_naive: -1177.00
# Ep. 205, Ep.Timesteps 24, Episode Reward: -947.81Ep. 205, Ep.Timesteps 24, Episode Reward_naive: -1035.00
# Ep. 206, Ep.Timesteps 24, Episode Reward: -998.69Ep. 206, Ep.Timesteps 24, Episode Reward_naive: -1086.00
# Ep. 207, Ep.Timesteps 24, Episode Reward: -752.08Ep. 207, Ep.Timesteps 24, Episode Reward_naive: -820.00
# Ep. 208, Ep.Timesteps 24, Episode Reward: -735.55Ep. 208, Ep.Timesteps 24, Episode Reward_naive: -802.00
# Ep. 209, Ep.Timesteps 24, Episode Reward: -1050.83Ep. 209, Ep.Timesteps 24, Episode Reward_naive: -1150.00
# Ep. 210, Ep.Timesteps 24, Episode Reward: -867.63Ep. 210, Ep.Timesteps 24, Episode Reward_naive: -951.00
# Ep. 211, Ep.Timesteps 24, Episode Reward: -837.99Ep. 211, Ep.Timesteps 24, Episode Reward_naive: -917.00
# Ep. 212, Ep.Timesteps 24, Episode Reward: -1005.47Ep. 212, Ep.Timesteps 24, Episode Reward_naive: -1104.00
# Ep. 213, Ep.Timesteps 24, Episode Reward: -925.24Ep. 213, Ep.Timesteps 24, Episode Reward_naive: -1013.00
# Ep. 214, Ep.Timesteps 24, Episode Reward: -767.70Ep. 214, Ep.Timesteps 24, Episode Reward_naive: -841.00
# Ep. 215, Ep.Timesteps 24, Episode Reward: -821.87Ep. 215, Ep.Timesteps 24, Episode Reward_naive: -900.00
# Ep. 216, Ep.Timesteps 24, Episode Reward: -974.60Ep. 216, Ep.Timesteps 24, Episode Reward_naive: -1069.00
# Ep. 217, Ep.Timesteps 24, Episode Reward: -978.98Ep. 217, Ep.Timesteps 24, Episode Reward_naive: -1078.00
# Ep. 218, Ep.Timesteps 24, Episode Reward: -1041.25Ep. 218, Ep.Timesteps 24, Episode Reward_naive: -1140.00
# Ep. 219, Ep.Timesteps 24, Episode Reward: -1027.13Ep. 219, Ep.Timesteps 24, Episode Reward_naive: -1122.00
# Ep. 220, Ep.Timesteps 24, Episode Reward: -859.80Ep. 220, Ep.Timesteps 24, Episode Reward_naive: -942.00
# Ep. 221, Ep.Timesteps 24, Episode Reward: -795.00Ep. 221, Ep.Timesteps 24, Episode Reward_naive: -872.00
# Ep. 222, Ep.Timesteps 24, Episode Reward: -868.82Ep. 222, Ep.Timesteps 24, Episode Reward_naive: -950.00
# Ep. 223, Ep.Timesteps 24, Episode Reward: -918.19Ep. 223, Ep.Timesteps 24, Episode Reward_naive: -1007.00
# Ep. 224, Ep.Timesteps 24, Episode Reward: -985.95Ep. 224, Ep.Timesteps 24, Episode Reward_naive: -1080.00
# Ep. 225, Ep.Timesteps 24, Episode Reward: -1069.10Ep. 225, Ep.Timesteps 24, Episode Reward_naive: -1170.00
# Ep. 226, Ep.Timesteps 24, Episode Reward: -974.65Ep. 226, Ep.Timesteps 24, Episode Reward_naive: -981.00
# Ep. 227, Ep.Timesteps 24, Episode Reward: -828.60Ep. 227, Ep.Timesteps 24, Episode Reward_naive: -880.00
# Ep. 228, Ep.Timesteps 24, Episode Reward: -840.97Ep. 228, Ep.Timesteps 24, Episode Reward_naive: -911.00
# Ep. 229, Ep.Timesteps 24, Episode Reward: -795.02Ep. 229, Ep.Timesteps 24, Episode Reward_naive: -864.00
# Ep. 230, Ep.Timesteps 24, Episode Reward: -847.76Ep. 230, Ep.Timesteps 24, Episode Reward_naive: -891.00
# Ep. 231, Ep.Timesteps 24, Episode Reward: -946.58Ep. 231, Ep.Timesteps 24, Episode Reward_naive: -937.00
# Ep. 232, Ep.Timesteps 24, Episode Reward: -937.22Ep. 232, Ep.Timesteps 24, Episode Reward_naive: -931.00
# Ep. 233, Ep.Timesteps 24, Episode Reward: -911.33Ep. 233, Ep.Timesteps 24, Episode Reward_naive: -948.00
# Ep. 234, Ep.Timesteps 24, Episode Reward: -669.88Ep. 234, Ep.Timesteps 24, Episode Reward_naive: -726.00
# Ep. 235, Ep.Timesteps 24, Episode Reward: -989.33Ep. 235, Ep.Timesteps 24, Episode Reward_naive: -990.00
# Ep. 236, Ep.Timesteps 24, Episode Reward: -1021.79Ep. 236, Ep.Timesteps 24, Episode Reward_naive: -1004.00
# Ep. 237, Ep.Timesteps 24, Episode Reward: -931.54Ep. 237, Ep.Timesteps 24, Episode Reward_naive: -908.00
# Ep. 238, Ep.Timesteps 24, Episode Reward: -960.14Ep. 238, Ep.Timesteps 24, Episode Reward_naive: -908.00
# Ep. 239, Ep.Timesteps 24, Episode Reward: -993.66Ep. 239, Ep.Timesteps 24, Episode Reward_naive: -1006.00
# Ep. 240, Ep.Timesteps 24, Episode Reward: -906.76Ep. 240, Ep.Timesteps 24, Episode Reward_naive: -884.00
# Ep. 241, Ep.Timesteps 24, Episode Reward: -1045.74Ep. 241, Ep.Timesteps 24, Episode Reward_naive: -1067.00
# Ep. 242, Ep.Timesteps 24, Episode Reward: -844.65Ep. 242, Ep.Timesteps 24, Episode Reward_naive: -803.00
# Ep. 243, Ep.Timesteps 24, Episode Reward: -791.17Ep. 243, Ep.Timesteps 24, Episode Reward_naive: -815.00
# Ep. 244, Ep.Timesteps 24, Episode Reward: -789.22Ep. 244, Ep.Timesteps 24, Episode Reward_naive: -776.00
# Ep. 245, Ep.Timesteps 24, Episode Reward: -800.48Ep. 245, Ep.Timesteps 24, Episode Reward_naive: -806.00
# Ep. 246, Ep.Timesteps 24, Episode Reward: -723.56Ep. 246, Ep.Timesteps 24, Episode Reward_naive: -717.00
# Ep. 247, Ep.Timesteps 24, Episode Reward: -607.44Ep. 247, Ep.Timesteps 24, Episode Reward_naive: -572.00
# Ep. 248, Ep.Timesteps 24, Episode Reward: -721.56Ep. 248, Ep.Timesteps 24, Episode Reward_naive: -718.00
# Ep. 249, Ep.Timesteps 24, Episode Reward: -898.23Ep. 249, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 250, Ep.Timesteps 24, Episode Reward: -610.11Ep. 250, Ep.Timesteps 24, Episode Reward_naive: -588.00
# Ep. 251, Ep.Timesteps 24, Episode Reward: -711.59Ep. 251, Ep.Timesteps 24, Episode Reward_naive: -688.00
# Ep. 252, Ep.Timesteps 24, Episode Reward: -889.88Ep. 252, Ep.Timesteps 24, Episode Reward_naive: -957.00
# Ep. 253, Ep.Timesteps 24, Episode Reward: -1071.47Ep. 253, Ep.Timesteps 24, Episode Reward_naive: -1159.00
# Ep. 254, Ep.Timesteps 24, Episode Reward: -955.73Ep. 254, Ep.Timesteps 24, Episode Reward_naive: -942.00
# Ep. 255, Ep.Timesteps 24, Episode Reward: -564.20Ep. 255, Ep.Timesteps 24, Episode Reward_naive: -599.00
# Ep. 256, Ep.Timesteps 24, Episode Reward: -793.17Ep. 256, Ep.Timesteps 24, Episode Reward_naive: -850.00
# Ep. 257, Ep.Timesteps 24, Episode Reward: -771.68Ep. 257, Ep.Timesteps 24, Episode Reward_naive: -830.00
# Ep. 258, Ep.Timesteps 24, Episode Reward: -892.06Ep. 258, Ep.Timesteps 24, Episode Reward_naive: -961.00
# Ep. 259, Ep.Timesteps 24, Episode Reward: -890.33Ep. 259, Ep.Timesteps 24, Episode Reward_naive: -942.00
# Ep. 260, Ep.Timesteps 24, Episode Reward: -833.05Ep. 260, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 261, Ep.Timesteps 24, Episode Reward: -934.74Ep. 261, Ep.Timesteps 24, Episode Reward_naive: -1015.00
# Ep. 262, Ep.Timesteps 24, Episode Reward: -995.08Ep. 262, Ep.Timesteps 24, Episode Reward_naive: -1083.00
# Ep. 263, Ep.Timesteps 24, Episode Reward: -838.48Ep. 263, Ep.Timesteps 24, Episode Reward_naive: -911.00
# Ep. 264, Ep.Timesteps 24, Episode Reward: -803.50Ep. 264, Ep.Timesteps 24, Episode Reward_naive: -872.00
# Ep. 265, Ep.Timesteps 24, Episode Reward: -819.63Ep. 265, Ep.Timesteps 24, Episode Reward_naive: -890.00
# Ep. 266, Ep.Timesteps 24, Episode Reward: -854.21Ep. 266, Ep.Timesteps 24, Episode Reward_naive: -925.00
# Ep. 267, Ep.Timesteps 24, Episode Reward: -960.47Ep. 267, Ep.Timesteps 24, Episode Reward_naive: -1042.00
# Ep. 268, Ep.Timesteps 24, Episode Reward: -710.96Ep. 268, Ep.Timesteps 24, Episode Reward_naive: -750.00
# Ep. 269, Ep.Timesteps 24, Episode Reward: -951.80Ep. 269, Ep.Timesteps 24, Episode Reward_naive: -1020.00
# Ep. 270, Ep.Timesteps 24, Episode Reward: -1019.49Ep. 270, Ep.Timesteps 24, Episode Reward_naive: -1092.00
# Ep. 271, Ep.Timesteps 24, Episode Reward: -834.77Ep. 271, Ep.Timesteps 24, Episode Reward_naive: -889.00
# Ep. 272, Ep.Timesteps 24, Episode Reward: -681.46Ep. 272, Ep.Timesteps 24, Episode Reward_naive: -721.00
# Ep. 273, Ep.Timesteps 24, Episode Reward: -1028.74Ep. 273, Ep.Timesteps 24, Episode Reward_naive: -1101.00
# Ep. 274, Ep.Timesteps 24, Episode Reward: -1102.24Ep. 274, Ep.Timesteps 24, Episode Reward_naive: -1182.00
# Ep. 275, Ep.Timesteps 24, Episode Reward: -850.83Ep. 275, Ep.Timesteps 24, Episode Reward_naive: -907.00
# Ep. 276, Ep.Timesteps 24, Episode Reward: -823.89Ep. 276, Ep.Timesteps 24, Episode Reward_naive: -884.00
# Ep. 277, Ep.Timesteps 24, Episode Reward: -847.71Ep. 277, Ep.Timesteps 24, Episode Reward_naive: -908.00
# Ep. 278, Ep.Timesteps 24, Episode Reward: -1058.44Ep. 278, Ep.Timesteps 24, Episode Reward_naive: -1138.00
# Ep. 279, Ep.Timesteps 24, Episode Reward: -786.14Ep. 279, Ep.Timesteps 24, Episode Reward_naive: -847.00
# Ep. 280, Ep.Timesteps 24, Episode Reward: -956.88Ep. 280, Ep.Timesteps 24, Episode Reward_naive: -1031.00
# Ep. 281, Ep.Timesteps 24, Episode Reward: -781.29Ep. 281, Ep.Timesteps 24, Episode Reward_naive: -843.00
# Ep. 282, Ep.Timesteps 24, Episode Reward: -836.77Ep. 282, Ep.Timesteps 24, Episode Reward_naive: -905.00
# Ep. 283, Ep.Timesteps 24, Episode Reward: -923.67Ep. 283, Ep.Timesteps 24, Episode Reward_naive: -992.00
# Ep. 284, Ep.Timesteps 24, Episode Reward: -824.11Ep. 284, Ep.Timesteps 24, Episode Reward_naive: -890.00
# Ep. 285, Ep.Timesteps 24, Episode Reward: -999.71Ep. 285, Ep.Timesteps 24, Episode Reward_naive: -1084.00
# Ep. 286, Ep.Timesteps 24, Episode Reward: -897.01Ep. 286, Ep.Timesteps 24, Episode Reward_naive: -972.00
# Ep. 287, Ep.Timesteps 24, Episode Reward: -703.29Ep. 287, Ep.Timesteps 24, Episode Reward_naive: -757.00
# Ep. 288, Ep.Timesteps 24, Episode Reward: -659.14Ep. 288, Ep.Timesteps 24, Episode Reward_naive: -711.00
# Ep. 289, Ep.Timesteps 24, Episode Reward: -1024.13Ep. 289, Ep.Timesteps 24, Episode Reward_naive: -1112.00
# Ep. 290, Ep.Timesteps 24, Episode Reward: -1088.34Ep. 290, Ep.Timesteps 24, Episode Reward_naive: -1185.00
# Ep. 291, Ep.Timesteps 24, Episode Reward: -784.65Ep. 291, Ep.Timesteps 24, Episode Reward_naive: -845.00
# Ep. 292, Ep.Timesteps 24, Episode Reward: -866.45Ep. 292, Ep.Timesteps 24, Episode Reward_naive: -942.00
# Ep. 293, Ep.Timesteps 24, Episode Reward: -883.81Ep. 293, Ep.Timesteps 24, Episode Reward_naive: -962.00
# Ep. 294, Ep.Timesteps 24, Episode Reward: -777.47Ep. 294, Ep.Timesteps 24, Episode Reward_naive: -846.00
# Ep. 295, Ep.Timesteps 24, Episode Reward: -815.85Ep. 295, Ep.Timesteps 24, Episode Reward_naive: -889.00
# Ep. 296, Ep.Timesteps 24, Episode Reward: -759.99Ep. 296, Ep.Timesteps 24, Episode Reward_naive: -822.00
# Ep. 297, Ep.Timesteps 24, Episode Reward: -850.86Ep. 297, Ep.Timesteps 24, Episode Reward_naive: -924.00
# Ep. 298, Ep.Timesteps 24, Episode Reward: -966.86Ep. 298, Ep.Timesteps 24, Episode Reward_naive: -1050.00
# Ep. 299, Ep.Timesteps 24, Episode Reward: -891.97Ep. 299, Ep.Timesteps 24, Episode Reward_naive: -968.00
# Ep. 300, Ep.Timesteps 24, Episode Reward: -886.03Ep. 300, Ep.Timesteps 24, Episode Reward_naive: -962.00
# Ep. 301, Ep.Timesteps 24, Episode Reward: -913.52Ep. 301, Ep.Timesteps 24, Episode Reward_naive: -998.00
# Ep. 302, Ep.Timesteps 24, Episode Reward: -870.71Ep. 302, Ep.Timesteps 24, Episode Reward_naive: -949.00
# Ep. 303, Ep.Timesteps 24, Episode Reward: -862.32Ep. 303, Ep.Timesteps 24, Episode Reward_naive: -941.00
# Ep. 304, Ep.Timesteps 24, Episode Reward: -946.36Ep. 304, Ep.Timesteps 24, Episode Reward_naive: -1029.00
# Ep. 305, Ep.Timesteps 24, Episode Reward: -799.03Ep. 305, Ep.Timesteps 24, Episode Reward_naive: -830.00
# Ep. 306, Ep.Timesteps 24, Episode Reward: -774.67Ep. 306, Ep.Timesteps 24, Episode Reward_naive: -846.00
# Ep. 307, Ep.Timesteps 24, Episode Reward: -828.47Ep. 307, Ep.Timesteps 24, Episode Reward_naive: -904.00
# Ep. 308, Ep.Timesteps 24, Episode Reward: -770.00Ep. 308, Ep.Timesteps 24, Episode Reward_naive: -842.00
# Ep. 309, Ep.Timesteps 24, Episode Reward: -800.70Ep. 309, Ep.Timesteps 24, Episode Reward_naive: -876.00
# Ep. 310, Ep.Timesteps 24, Episode Reward: -817.14Ep. 310, Ep.Timesteps 24, Episode Reward_naive: -893.00
# Ep. 311, Ep.Timesteps 24, Episode Reward: -1012.07Ep. 311, Ep.Timesteps 24, Episode Reward_naive: -1106.00
# Ep. 312, Ep.Timesteps 24, Episode Reward: -936.05Ep. 312, Ep.Timesteps 24, Episode Reward_naive: -1026.00
# Ep. 313, Ep.Timesteps 24, Episode Reward: -792.65Ep. 313, Ep.Timesteps 24, Episode Reward_naive: -813.00
# Ep. 314, Ep.Timesteps 24, Episode Reward: -1005.64Ep. 314, Ep.Timesteps 24, Episode Reward_naive: -1104.00
# Ep. 315, Ep.Timesteps 24, Episode Reward: -980.36Ep. 315, Ep.Timesteps 24, Episode Reward_naive: -1072.00
# Ep. 316, Ep.Timesteps 24, Episode Reward: -738.06Ep. 316, Ep.Timesteps 24, Episode Reward_naive: -807.00
# Ep. 317, Ep.Timesteps 24, Episode Reward: -841.06Ep. 317, Ep.Timesteps 24, Episode Reward_naive: -921.00
# Ep. 318, Ep.Timesteps 24, Episode Reward: -957.18Ep. 318, Ep.Timesteps 24, Episode Reward_naive: -1054.00
# Ep. 319, Ep.Timesteps 24, Episode Reward: -966.77Ep. 319, Ep.Timesteps 24, Episode Reward_naive: -1062.00
# Ep. 320, Ep.Timesteps 24, Episode Reward: -823.39Ep. 320, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 321, Ep.Timesteps 24, Episode Reward: -1030.55Ep. 321, Ep.Timesteps 24, Episode Reward_naive: -1131.00
# Ep. 322, Ep.Timesteps 24, Episode Reward: -1028.40Ep. 322, Ep.Timesteps 24, Episode Reward_naive: -1130.00
# Ep. 323, Ep.Timesteps 24, Episode Reward: -759.83Ep. 323, Ep.Timesteps 24, Episode Reward_naive: -831.00
# Ep. 324, Ep.Timesteps 24, Episode Reward: -833.29Ep. 324, Ep.Timesteps 24, Episode Reward_naive: -917.00
# Ep. 325, Ep.Timesteps 24, Episode Reward: -985.59Ep. 325, Ep.Timesteps 24, Episode Reward_naive: -1083.00
# Ep. 326, Ep.Timesteps 24, Episode Reward: -865.98Ep. 326, Ep.Timesteps 24, Episode Reward_naive: -950.00
# Ep. 327, Ep.Timesteps 24, Episode Reward: -1135.64Ep. 327, Ep.Timesteps 24, Episode Reward_naive: -1249.00
# Ep. 328, Ep.Timesteps 24, Episode Reward: -767.98Ep. 328, Ep.Timesteps 24, Episode Reward_naive: -841.00
# Ep. 329, Ep.Timesteps 24, Episode Reward: -829.12Ep. 329, Ep.Timesteps 24, Episode Reward_naive: -911.00
# Ep. 330, Ep.Timesteps 24, Episode Reward: -1110.77Ep. 330, Ep.Timesteps 24, Episode Reward_naive: -1221.00
# Ep. 331, Ep.Timesteps 24, Episode Reward: -1092.74Ep. 331, Ep.Timesteps 24, Episode Reward_naive: -1203.00
# Ep. 332, Ep.Timesteps 24, Episode Reward: -1044.32Ep. 332, Ep.Timesteps 24, Episode Reward_naive: -1150.00
# Ep. 333, Ep.Timesteps 24, Episode Reward: -881.59Ep. 333, Ep.Timesteps 24, Episode Reward_naive: -968.00
# Ep. 334, Ep.Timesteps 24, Episode Reward: -912.70Ep. 334, Ep.Timesteps 24, Episode Reward_naive: -1005.00
# Ep. 335, Ep.Timesteps 24, Episode Reward: -1076.40Ep. 335, Ep.Timesteps 24, Episode Reward_naive: -1186.00
# Ep. 336, Ep.Timesteps 24, Episode Reward: -965.74Ep. 336, Ep.Timesteps 24, Episode Reward_naive: -1065.00
# Ep. 337, Ep.Timesteps 24, Episode Reward: -919.68Ep. 337, Ep.Timesteps 24, Episode Reward_naive: -1012.00
# Ep. 338, Ep.Timesteps 24, Episode Reward: -644.73Ep. 338, Ep.Timesteps 24, Episode Reward_naive: -709.00
# Ep. 339, Ep.Timesteps 24, Episode Reward: -1087.64Ep. 339, Ep.Timesteps 24, Episode Reward_naive: -1196.00
# Ep. 340, Ep.Timesteps 24, Episode Reward: -1019.13Ep. 340, Ep.Timesteps 24, Episode Reward_naive: -1121.00
# Ep. 341, Ep.Timesteps 24, Episode Reward: -819.49Ep. 341, Ep.Timesteps 24, Episode Reward_naive: -902.00
# Ep. 342, Ep.Timesteps 24, Episode Reward: -764.16Ep. 342, Ep.Timesteps 24, Episode Reward_naive: -841.00
# Ep. 343, Ep.Timesteps 24, Episode Reward: -1032.04Ep. 343, Ep.Timesteps 24, Episode Reward_naive: -1137.00
# Ep. 344, Ep.Timesteps 24, Episode Reward: -957.42Ep. 344, Ep.Timesteps 24, Episode Reward_naive: -1056.00
# Ep. 345, Ep.Timesteps 24, Episode Reward: -938.16Ep. 345, Ep.Timesteps 24, Episode Reward_naive: -1028.00
# Ep. 346, Ep.Timesteps 24, Episode Reward: -879.52Ep. 346, Ep.Timesteps 24, Episode Reward_naive: -968.00
# Ep. 347, Ep.Timesteps 24, Episode Reward: -909.87Ep. 347, Ep.Timesteps 24, Episode Reward_naive: -1000.00
# Ep. 348, Ep.Timesteps 24, Episode Reward: -960.94Ep. 348, Ep.Timesteps 24, Episode Reward_naive: -1061.00
# Ep. 349, Ep.Timesteps 24, Episode Reward: -865.96Ep. 349, Ep.Timesteps 24, Episode Reward_naive: -952.00
# Ep. 350, Ep.Timesteps 24, Episode Reward: -1015.91Ep. 350, Ep.Timesteps 24, Episode Reward_naive: -1118.00
# Ep. 351, Ep.Timesteps 24, Episode Reward: -828.59Ep. 351, Ep.Timesteps 24, Episode Reward_naive: -910.00
# Ep. 352, Ep.Timesteps 24, Episode Reward: -876.77Ep. 352, Ep.Timesteps 24, Episode Reward_naive: -966.00
# Ep. 353, Ep.Timesteps 24, Episode Reward: -798.81Ep. 353, Ep.Timesteps 24, Episode Reward_naive: -873.00
# Ep. 354, Ep.Timesteps 24, Episode Reward: -825.65Ep. 354, Ep.Timesteps 24, Episode Reward_naive: -909.00
# Ep. 355, Ep.Timesteps 24, Episode Reward: -839.34Ep. 355, Ep.Timesteps 24, Episode Reward_naive: -922.00
# Ep. 356, Ep.Timesteps 24, Episode Reward: -658.91Ep. 356, Ep.Timesteps 24, Episode Reward_naive: -723.00
# Ep. 357, Ep.Timesteps 24, Episode Reward: -860.61Ep. 357, Ep.Timesteps 24, Episode Reward_naive: -948.00
# Ep. 358, Ep.Timesteps 24, Episode Reward: -945.81Ep. 358, Ep.Timesteps 24, Episode Reward_naive: -1040.00
# Ep. 359, Ep.Timesteps 24, Episode Reward: -976.98Ep. 359, Ep.Timesteps 24, Episode Reward_naive: -1078.00
# Ep. 360, Ep.Timesteps 24, Episode Reward: -930.57Ep. 360, Ep.Timesteps 24, Episode Reward_naive: -1024.00
# Ep. 361, Ep.Timesteps 24, Episode Reward: -840.37Ep. 361, Ep.Timesteps 24, Episode Reward_naive: -924.00
# Ep. 362, Ep.Timesteps 24, Episode Reward: -671.95Ep. 362, Ep.Timesteps 24, Episode Reward_naive: -736.00
# Ep. 363, Ep.Timesteps 24, Episode Reward: -814.33Ep. 363, Ep.Timesteps 24, Episode Reward_naive: -896.00
# Ep. 364, Ep.Timesteps 24, Episode Reward: -836.02Ep. 364, Ep.Timesteps 24, Episode Reward_naive: -918.00
# Ep. 365, Ep.Timesteps 24, Episode Reward: -1055.12Ep. 365, Ep.Timesteps 24, Episode Reward_naive: -1161.00
# Ep. 366, Ep.Timesteps 24, Episode Reward: -765.51Ep. 366, Ep.Timesteps 24, Episode Reward_naive: -845.00
# Ep. 367, Ep.Timesteps 24, Episode Reward: -753.99Ep. 367, Ep.Timesteps 24, Episode Reward_naive: -828.00
# Ep. 368, Ep.Timesteps 24, Episode Reward: -845.49Ep. 368, Ep.Timesteps 24, Episode Reward_naive: -927.00
# Ep. 369, Ep.Timesteps 24, Episode Reward: -1068.59Ep. 369, Ep.Timesteps 24, Episode Reward_naive: -1175.00
# Ep. 370, Ep.Timesteps 24, Episode Reward: -765.45Ep. 370, Ep.Timesteps 24, Episode Reward_naive: -838.00
# Ep. 371, Ep.Timesteps 24, Episode Reward: -877.98Ep. 371, Ep.Timesteps 24, Episode Reward_naive: -963.00
# Ep. 372, Ep.Timesteps 24, Episode Reward: -789.15Ep. 372, Ep.Timesteps 24, Episode Reward_naive: -866.00
# Ep. 373, Ep.Timesteps 24, Episode Reward: -845.44Ep. 373, Ep.Timesteps 24, Episode Reward_naive: -923.00
# Ep. 374, Ep.Timesteps 24, Episode Reward: -667.46Ep. 374, Ep.Timesteps 24, Episode Reward_naive: -732.00
# Ep. 375, Ep.Timesteps 24, Episode Reward: -994.55Ep. 375, Ep.Timesteps 24, Episode Reward_naive: -1093.00
# Ep. 376, Ep.Timesteps 24, Episode Reward: -793.10Ep. 376, Ep.Timesteps 24, Episode Reward_naive: -871.00
# Ep. 377, Ep.Timesteps 24, Episode Reward: -745.72Ep. 377, Ep.Timesteps 24, Episode Reward_naive: -818.00
# Ep. 378, Ep.Timesteps 24, Episode Reward: -921.69Ep. 378, Ep.Timesteps 24, Episode Reward_naive: -1012.00
# Ep. 379, Ep.Timesteps 24, Episode Reward: -1150.25Ep. 379, Ep.Timesteps 24, Episode Reward_naive: -1265.00
# Ep. 380, Ep.Timesteps 24, Episode Reward: -964.17Ep. 380, Ep.Timesteps 24, Episode Reward_naive: -1060.00
# Ep. 381, Ep.Timesteps 24, Episode Reward: -881.66Ep. 381, Ep.Timesteps 24, Episode Reward_naive: -970.00
# Ep. 382, Ep.Timesteps 24, Episode Reward: -1029.26Ep. 382, Ep.Timesteps 24, Episode Reward_naive: -1131.00
# Ep. 383, Ep.Timesteps 24, Episode Reward: -936.96Ep. 383, Ep.Timesteps 24, Episode Reward_naive: -1028.00
# Ep. 384, Ep.Timesteps 24, Episode Reward: -819.92Ep. 384, Ep.Timesteps 24, Episode Reward_naive: -900.00
# Ep. 385, Ep.Timesteps 24, Episode Reward: -816.44Ep. 385, Ep.Timesteps 24, Episode Reward_naive: -893.00
# Ep. 386, Ep.Timesteps 24, Episode Reward: -931.25Ep. 386, Ep.Timesteps 24, Episode Reward_naive: -1027.00
# Ep. 387, Ep.Timesteps 24, Episode Reward: -974.32Ep. 387, Ep.Timesteps 24, Episode Reward_naive: -1071.00
# Ep. 388, Ep.Timesteps 24, Episode Reward: -831.27Ep. 388, Ep.Timesteps 24, Episode Reward_naive: -914.00
# Ep. 389, Ep.Timesteps 24, Episode Reward: -728.36Ep. 389, Ep.Timesteps 24, Episode Reward_naive: -799.00
# Ep. 390, Ep.Timesteps 24, Episode Reward: -628.21Ep. 390, Ep.Timesteps 24, Episode Reward_naive: -688.00
# Ep. 391, Ep.Timesteps 24, Episode Reward: -960.47Ep. 391, Ep.Timesteps 24, Episode Reward_naive: -1055.00
# Ep. 392, Ep.Timesteps 24, Episode Reward: -818.49Ep. 392, Ep.Timesteps 24, Episode Reward_naive: -898.00
# Ep. 393, Ep.Timesteps 24, Episode Reward: -644.00Ep. 393, Ep.Timesteps 24, Episode Reward_naive: -707.00
# Ep. 394, Ep.Timesteps 24, Episode Reward: -899.61Ep. 394, Ep.Timesteps 24, Episode Reward_naive: -989.00
# Ep. 395, Ep.Timesteps 24, Episode Reward: -1035.99Ep. 395, Ep.Timesteps 24, Episode Reward_naive: -1137.00
# Ep. 396, Ep.Timesteps 24, Episode Reward: -858.82Ep. 396, Ep.Timesteps 24, Episode Reward_naive: -942.00
# Ep. 397, Ep.Timesteps 24, Episode Reward: -776.16Ep. 397, Ep.Timesteps 24, Episode Reward_naive: -852.00
# Ep. 398, Ep.Timesteps 24, Episode Reward: -1005.46Ep. 398, Ep.Timesteps 24, Episode Reward_naive: -1107.00
# Ep. 399, Ep.Timesteps 24, Episode Reward: -997.25Ep. 399, Ep.Timesteps 24, Episode Reward_naive: -1094.00
# Ep. 400, Ep.Timesteps 24, Episode Reward: -799.57Ep. 400, Ep.Timesteps 24, Episode Reward_naive: -875.00
# Ep. 401, Ep.Timesteps 24, Episode Reward: -1062.26Ep. 401, Ep.Timesteps 24, Episode Reward_naive: -1163.00
# Ep. 402, Ep.Timesteps 24, Episode Reward: -745.48Ep. 402, Ep.Timesteps 24, Episode Reward_naive: -814.00
# Ep. 403, Ep.Timesteps 24, Episode Reward: -971.09Ep. 403, Ep.Timesteps 24, Episode Reward_naive: -1059.00
# Ep. 404, Ep.Timesteps 24, Episode Reward: -911.86Ep. 404, Ep.Timesteps 24, Episode Reward_naive: -998.00
# Ep. 405, Ep.Timesteps 24, Episode Reward: -1061.12Ep. 405, Ep.Timesteps 24, Episode Reward_naive: -1159.00
# Ep. 406, Ep.Timesteps 24, Episode Reward: -800.95Ep. 406, Ep.Timesteps 24, Episode Reward_naive: -873.00
# Ep. 407, Ep.Timesteps 24, Episode Reward: -797.25Ep. 407, Ep.Timesteps 24, Episode Reward_naive: -871.00
# Ep. 408, Ep.Timesteps 24, Episode Reward: -782.00Ep. 408, Ep.Timesteps 24, Episode Reward_naive: -853.00
# Ep. 409, Ep.Timesteps 24, Episode Reward: -589.16Ep. 409, Ep.Timesteps 24, Episode Reward_naive: -640.00
# Ep. 410, Ep.Timesteps 24, Episode Reward: -972.39Ep. 410, Ep.Timesteps 24, Episode Reward_naive: -1063.00
# Ep. 411, Ep.Timesteps 24, Episode Reward: -850.89Ep. 411, Ep.Timesteps 24, Episode Reward_naive: -927.00
# Ep. 412, Ep.Timesteps 24, Episode Reward: -919.61Ep. 412, Ep.Timesteps 24, Episode Reward_naive: -1000.00
# Ep. 413, Ep.Timesteps 24, Episode Reward: -811.60Ep. 413, Ep.Timesteps 24, Episode Reward_naive: -885.00
# Ep. 414, Ep.Timesteps 24, Episode Reward: -957.68Ep. 414, Ep.Timesteps 24, Episode Reward_naive: -1042.00
# Ep. 415, Ep.Timesteps 24, Episode Reward: -964.03Ep. 415, Ep.Timesteps 24, Episode Reward_naive: -1055.00
# Ep. 416, Ep.Timesteps 24, Episode Reward: -977.74Ep. 416, Ep.Timesteps 24, Episode Reward_naive: -1068.00
# Ep. 417, Ep.Timesteps 24, Episode Reward: -841.79Ep. 417, Ep.Timesteps 24, Episode Reward_naive: -921.00
# Ep. 418, Ep.Timesteps 24, Episode Reward: -893.73Ep. 418, Ep.Timesteps 24, Episode Reward_naive: -976.00
# Ep. 419, Ep.Timesteps 24, Episode Reward: -1000.08Ep. 419, Ep.Timesteps 24, Episode Reward_naive: -1095.00
# Ep. 420, Ep.Timesteps 24, Episode Reward: -924.50Ep. 420, Ep.Timesteps 24, Episode Reward_naive: -1009.00
# Ep. 421, Ep.Timesteps 24, Episode Reward: -752.55Ep. 421, Ep.Timesteps 24, Episode Reward_naive: -818.00
# Ep. 422, Ep.Timesteps 24, Episode Reward: -920.45Ep. 422, Ep.Timesteps 24, Episode Reward_naive: -1006.00
# Ep. 423, Ep.Timesteps 24, Episode Reward: -955.70Ep. 423, Ep.Timesteps 24, Episode Reward_naive: -1046.00
# Ep. 424, Ep.Timesteps 24, Episode Reward: -840.27Ep. 424, Ep.Timesteps 24, Episode Reward_naive: -921.00
# Ep. 425, Ep.Timesteps 24, Episode Reward: -955.78Ep. 425, Ep.Timesteps 24, Episode Reward_naive: -1046.00
# Ep. 426, Ep.Timesteps 24, Episode Reward: -816.46Ep. 426, Ep.Timesteps 24, Episode Reward_naive: -886.00
# Ep. 427, Ep.Timesteps 24, Episode Reward: -782.58Ep. 427, Ep.Timesteps 24, Episode Reward_naive: -852.00
# Ep. 428, Ep.Timesteps 24, Episode Reward: -812.72Ep. 428, Ep.Timesteps 24, Episode Reward_naive: -887.00
# Ep. 429, Ep.Timesteps 24, Episode Reward: -834.91Ep. 429, Ep.Timesteps 24, Episode Reward_naive: -906.00
# Ep. 430, Ep.Timesteps 24, Episode Reward: -833.32Ep. 430, Ep.Timesteps 24, Episode Reward_naive: -905.00
# Ep. 431, Ep.Timesteps 24, Episode Reward: -1063.07Ep. 431, Ep.Timesteps 24, Episode Reward_naive: -1160.00
# Ep. 432, Ep.Timesteps 24, Episode Reward: -705.48Ep. 432, Ep.Timesteps 24, Episode Reward_naive: -770.00
# Ep. 433, Ep.Timesteps 24, Episode Reward: -794.39Ep. 433, Ep.Timesteps 24, Episode Reward_naive: -867.00
# Ep. 434, Ep.Timesteps 24, Episode Reward: -771.53Ep. 434, Ep.Timesteps 24, Episode Reward_naive: -830.00
# Ep. 435, Ep.Timesteps 24, Episode Reward: -769.39Ep. 435, Ep.Timesteps 24, Episode Reward_naive: -830.00
# Ep. 436, Ep.Timesteps 24, Episode Reward: -769.67Ep. 436, Ep.Timesteps 24, Episode Reward_naive: -829.00
# Ep. 437, Ep.Timesteps 24, Episode Reward: -924.82Ep. 437, Ep.Timesteps 24, Episode Reward_naive: -998.00
# Ep. 438, Ep.Timesteps 24, Episode Reward: -929.10Ep. 438, Ep.Timesteps 24, Episode Reward_naive: -1003.00
# Ep. 439, Ep.Timesteps 24, Episode Reward: -793.80Ep. 439, Ep.Timesteps 24, Episode Reward_naive: -860.00
# Ep. 440, Ep.Timesteps 24, Episode Reward: -986.27Ep. 440, Ep.Timesteps 24, Episode Reward_naive: -1067.00
# Ep. 441, Ep.Timesteps 24, Episode Reward: -796.62Ep. 441, Ep.Timesteps 24, Episode Reward_naive: -860.00
# Ep. 442, Ep.Timesteps 24, Episode Reward: -852.15Ep. 442, Ep.Timesteps 24, Episode Reward_naive: -917.00
# Ep. 443, Ep.Timesteps 24, Episode Reward: -1189.66Ep. 443, Ep.Timesteps 24, Episode Reward_naive: -1282.00
# Ep. 444, Ep.Timesteps 24, Episode Reward: -826.75Ep. 444, Ep.Timesteps 24, Episode Reward_naive: -891.00
# Ep. 445, Ep.Timesteps 24, Episode Reward: -862.21Ep. 445, Ep.Timesteps 24, Episode Reward_naive: -927.00
# Ep. 446, Ep.Timesteps 24, Episode Reward: -989.30Ep. 446, Ep.Timesteps 24, Episode Reward_naive: -1066.00
# Ep. 447, Ep.Timesteps 24, Episode Reward: -785.18Ep. 447, Ep.Timesteps 24, Episode Reward_naive: -843.00
# Ep. 448, Ep.Timesteps 24, Episode Reward: -832.09Ep. 448, Ep.Timesteps 24, Episode Reward_naive: -897.00
# Ep. 449, Ep.Timesteps 24, Episode Reward: -682.63Ep. 449, Ep.Timesteps 24, Episode Reward_naive: -730.00
# Ep. 450, Ep.Timesteps 24, Episode Reward: -911.22Ep. 450, Ep.Timesteps 24, Episode Reward_naive: -983.00
# Ep. 451, Ep.Timesteps 24, Episode Reward: -930.07Ep. 451, Ep.Timesteps 24, Episode Reward_naive: -973.00
# Ep. 452, Ep.Timesteps 24, Episode Reward: -836.84Ep. 452, Ep.Timesteps 24, Episode Reward_naive: -878.00
# Ep. 453, Ep.Timesteps 24, Episode Reward: -924.96Ep. 453, Ep.Timesteps 24, Episode Reward_naive: -975.00
# Ep. 454, Ep.Timesteps 24, Episode Reward: -906.65Ep. 454, Ep.Timesteps 24, Episode Reward_naive: -950.00
# Ep. 455, Ep.Timesteps 24, Episode Reward: -718.14Ep. 455, Ep.Timesteps 24, Episode Reward_naive: -746.00
# Ep. 456, Ep.Timesteps 24, Episode Reward: -1102.11Ep. 456, Ep.Timesteps 24, Episode Reward_naive: -1156.00
# ...
# Ep. 1854, Ep.Timesteps 24, Episode Reward: -927.79Ep. 1854, Ep.Timesteps 24, Episode Reward_naive: -842.00
# Ep. 1855, Ep.Timesteps 24, Episode Reward: -1021.39Ep. 1855, Ep.Timesteps 24, Episode Reward_naive: -921.00
# Ep. 1856, Ep.Timesteps 24, Episode Reward: -947.04Ep. 1856, Ep.Timesteps 24, Episode Reward_naive: -860.00
# Ep. 1857, Ep.Timesteps 24, Episode Reward: -855.24Ep. 1857, Ep.Timesteps 24, Episode Reward_naive: -776.00
# Ep. 1858, Ep.Timesteps 24, Episode Reward: -962.94Ep. 1858, Ep.Timesteps 24, Episode Reward_naive: -873.00
# Ep. 1859, Ep.Timesteps 24, Episode Reward: -889.09Ep. 1859, Ep.Timesteps 24, Episode Reward_naive: -808.00
# Ep. 1860, Ep.Timesteps 24, Episode Reward: -792.97Ep. 1860, Ep.Timesteps 24, Episode Reward_naive: -719.00
# Ep. 1861, Ep.Timesteps 24, Episode Reward: -960.55Ep. 1861, Ep.Timesteps 24, Episode Reward_naive: -871.00
# Ep. 1862, Ep.Timesteps 24, Episode Reward: -997.19Ep. 1862, Ep.Timesteps 24, Episode Reward_naive: -899.00
# Ep. 1863, Ep.Timesteps 24, Episode Reward: -924.60Ep. 1863, Ep.Timesteps 24, Episode Reward_naive: -841.00
# Ep. 1864, Ep.Timesteps 24, Episode Reward: -1146.77Ep. 1864, Ep.Timesteps 24, Episode Reward_naive: -1037.00
# Ep. 1865, Ep.Timesteps 24, Episode Reward: -1083.84Ep. 1865, Ep.Timesteps 24, Episode Reward_naive: -983.00
# Ep. 1866, Ep.Timesteps 24, Episode Reward: -702.61Ep. 1866, Ep.Timesteps 24, Episode Reward_naive: -636.00
# Ep. 1867, Ep.Timesteps 24, Episode Reward: -990.69Ep. 1867, Ep.Timesteps 24, Episode Reward_naive: -900.00
# Ep. 1868, Ep.Timesteps 24, Episode Reward: -1105.74Ep. 1868, Ep.Timesteps 24, Episode Reward_naive: -1000.00
# Ep. 1869, Ep.Timesteps 24, Episode Reward: -948.42Ep. 1869, Ep.Timesteps 24, Episode Reward_naive: -861.00
# Ep. 1870, Ep.Timesteps 24, Episode Reward: -953.50Ep. 1870, Ep.Timesteps 24, Episode Reward_naive: -864.00
# Ep. 1871, Ep.Timesteps 24, Episode Reward: -1048.40Ep. 1871, Ep.Timesteps 24, Episode Reward_naive: -951.00
# Ep. 1872, Ep.Timesteps 24, Episode Reward: -1134.79Ep. 1872, Ep.Timesteps 24, Episode Reward_naive: -1029.00
# Ep. 1873, Ep.Timesteps 24, Episode Reward: -1281.85Ep. 1873, Ep.Timesteps 24, Episode Reward_naive: -1165.00
# Ep. 1874, Ep.Timesteps 24, Episode Reward: -940.84Ep. 1874, Ep.Timesteps 24, Episode Reward_naive: -853.00
# Ep. 1875, Ep.Timesteps 24, Episode Reward: -859.53Ep. 1875, Ep.Timesteps 24, Episode Reward_naive: -780.00
# Ep. 1876, Ep.Timesteps 24, Episode Reward: -1041.49Ep. 1876, Ep.Timesteps 24, Episode Reward_naive: -947.00
# Ep. 1877, Ep.Timesteps 24, Episode Reward: -1008.47Ep. 1877, Ep.Timesteps 24, Episode Reward_naive: -891.00
# Ep. 1878, Ep.Timesteps 24, Episode Reward: -1120.38Ep. 1878, Ep.Timesteps 24, Episode Reward_naive: -1016.00
# Ep. 1879, Ep.Timesteps 24, Episode Reward: -1202.72Ep. 1879, Ep.Timesteps 24, Episode Reward_naive: -1028.00
# Ep. 1880, Ep.Timesteps 24, Episode Reward: -867.69Ep. 1880, Ep.Timesteps 24, Episode Reward_naive: -787.00
# Ep. 1881, Ep.Timesteps 24, Episode Reward: -1022.70Ep. 1881, Ep.Timesteps 24, Episode Reward_naive: -926.00
# Ep. 1882, Ep.Timesteps 24, Episode Reward: -947.79Ep. 1882, Ep.Timesteps 24, Episode Reward_naive: -858.00
# Ep. 1883, Ep.Timesteps 24, Episode Reward: -1191.58Ep. 1883, Ep.Timesteps 24, Episode Reward_naive: -1080.00
# Ep. 1884, Ep.Timesteps 24, Episode Reward: -994.50Ep. 1884, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 1885, Ep.Timesteps 24, Episode Reward: -994.05Ep. 1885, Ep.Timesteps 24, Episode Reward_naive: -904.00
# Ep. 1886, Ep.Timesteps 24, Episode Reward: -925.28Ep. 1886, Ep.Timesteps 24, Episode Reward_naive: -837.00
# Ep. 1887, Ep.Timesteps 24, Episode Reward: -1111.54Ep. 1887, Ep.Timesteps 24, Episode Reward_naive: -985.00
# Ep. 1888, Ep.Timesteps 24, Episode Reward: -1286.54Ep. 1888, Ep.Timesteps 24, Episode Reward_naive: -1114.00
# Ep. 1889, Ep.Timesteps 24, Episode Reward: -1174.96Ep. 1889, Ep.Timesteps 24, Episode Reward_naive: -1061.00
# Ep. 1890, Ep.Timesteps 24, Episode Reward: -922.72Ep. 1890, Ep.Timesteps 24, Episode Reward_naive: -837.00
# Ep. 1891, Ep.Timesteps 24, Episode Reward: -1084.04Ep. 1891, Ep.Timesteps 24, Episode Reward_naive: -982.00
# Ep. 1892, Ep.Timesteps 24, Episode Reward: -1132.17Ep. 1892, Ep.Timesteps 24, Episode Reward_naive: -1026.00
# Ep. 1893, Ep.Timesteps 24, Episode Reward: -1035.48Ep. 1893, Ep.Timesteps 24, Episode Reward_naive: -938.00
# Ep. 1894, Ep.Timesteps 24, Episode Reward: -1013.69Ep. 1894, Ep.Timesteps 24, Episode Reward_naive: -922.00
# Ep. 1895, Ep.Timesteps 24, Episode Reward: -950.15Ep. 1895, Ep.Timesteps 24, Episode Reward_naive: -860.00
# Ep. 1896, Ep.Timesteps 24, Episode Reward: -996.48Ep. 1896, Ep.Timesteps 24, Episode Reward_naive: -882.00
# Ep. 1897, Ep.Timesteps 24, Episode Reward: -941.39Ep. 1897, Ep.Timesteps 24, Episode Reward_naive: -852.00
# Ep. 1898, Ep.Timesteps 24, Episode Reward: -935.93Ep. 1898, Ep.Timesteps 24, Episode Reward_naive: -850.00
# Ep. 1899, Ep.Timesteps 24, Episode Reward: -1045.01Ep. 1899, Ep.Timesteps 24, Episode Reward_naive: -914.00
# Ep. 1900, Ep.Timesteps 24, Episode Reward: -933.37Ep. 1900, Ep.Timesteps 24, Episode Reward_naive: -843.00
# Ep. 1901, Ep.Timesteps 24, Episode Reward: -838.45Ep. 1901, Ep.Timesteps 24, Episode Reward_naive: -762.00
# Ep. 1902, Ep.Timesteps 24, Episode Reward: -719.83Ep. 1902, Ep.Timesteps 24, Episode Reward_naive: -652.00
# Ep. 1903, Ep.Timesteps 24, Episode Reward: -1227.42Ep. 1903, Ep.Timesteps 24, Episode Reward_naive: -1114.00
# Ep. 1904, Ep.Timesteps 24, Episode Reward: -1006.27Ep. 1904, Ep.Timesteps 24, Episode Reward_naive: -893.00
# Ep. 1905, Ep.Timesteps 24, Episode Reward: -900.46Ep. 1905, Ep.Timesteps 24, Episode Reward_naive: -817.00
# Ep. 1906, Ep.Timesteps 24, Episode Reward: -840.74Ep. 1906, Ep.Timesteps 24, Episode Reward_naive: -765.00
# Ep. 1907, Ep.Timesteps 24, Episode Reward: -980.16Ep. 1907, Ep.Timesteps 24, Episode Reward_naive: -877.00
# Ep. 1908, Ep.Timesteps 24, Episode Reward: -850.64Ep. 1908, Ep.Timesteps 24, Episode Reward_naive: -773.00
# Ep. 1909, Ep.Timesteps 24, Episode Reward: -1110.98Ep. 1909, Ep.Timesteps 24, Episode Reward_naive: -996.00
# Ep. 1910, Ep.Timesteps 24, Episode Reward: -865.21Ep. 1910, Ep.Timesteps 24, Episode Reward_naive: -786.00
# Ep. 1911, Ep.Timesteps 24, Episode Reward: -974.55Ep. 1911, Ep.Timesteps 24, Episode Reward_naive: -884.00
# Ep. 1912, Ep.Timesteps 24, Episode Reward: -1081.22Ep. 1912, Ep.Timesteps 24, Episode Reward_naive: -981.00
# Ep. 1913, Ep.Timesteps 24, Episode Reward: -1043.83Ep. 1913, Ep.Timesteps 24, Episode Reward_naive: -942.00
# Ep. 1914, Ep.Timesteps 24, Episode Reward: -983.00Ep. 1914, Ep.Timesteps 24, Episode Reward_naive: -891.00
# Ep. 1915, Ep.Timesteps 24, Episode Reward: -1051.09Ep. 1915, Ep.Timesteps 24, Episode Reward_naive: -954.00
# Ep. 1916, Ep.Timesteps 24, Episode Reward: -1170.18Ep. 1916, Ep.Timesteps 24, Episode Reward_naive: -1041.00
# Ep. 1917, Ep.Timesteps 24, Episode Reward: -1167.27Ep. 1917, Ep.Timesteps 24, Episode Reward_naive: -1057.00
# Ep. 1918, Ep.Timesteps 24, Episode Reward: -907.54Ep. 1918, Ep.Timesteps 24, Episode Reward_naive: -823.00
# Ep. 1919, Ep.Timesteps 24, Episode Reward: -1134.35Ep. 1919, Ep.Timesteps 24, Episode Reward_naive: -1027.00
# Ep. 1920, Ep.Timesteps 24, Episode Reward: -1020.42Ep. 1920, Ep.Timesteps 24, Episode Reward_naive: -926.00
# Ep. 1921, Ep.Timesteps 24, Episode Reward: -975.62Ep. 1921, Ep.Timesteps 24, Episode Reward_naive: -887.00
# Ep. 1922, Ep.Timesteps 24, Episode Reward: -862.25Ep. 1922, Ep.Timesteps 24, Episode Reward_naive: -783.00
# Ep. 1923, Ep.Timesteps 24, Episode Reward: -1104.35Ep. 1923, Ep.Timesteps 24, Episode Reward_naive: -1002.00
# Ep. 1924, Ep.Timesteps 24, Episode Reward: -1242.88Ep. 1924, Ep.Timesteps 24, Episode Reward_naive: -1129.00
# Ep. 1925, Ep.Timesteps 24, Episode Reward: -836.52Ep. 1925, Ep.Timesteps 24, Episode Reward_naive: -760.00
# Ep. 1926, Ep.Timesteps 24, Episode Reward: -1017.99Ep. 1926, Ep.Timesteps 24, Episode Reward_naive: -923.00
# Ep. 1927, Ep.Timesteps 24, Episode Reward: -1123.18Ep. 1927, Ep.Timesteps 24, Episode Reward_naive: -999.00
# Ep. 1928, Ep.Timesteps 24, Episode Reward: -1096.15Ep. 1928, Ep.Timesteps 24, Episode Reward_naive: -973.00
# Ep. 1929, Ep.Timesteps 24, Episode Reward: -978.84Ep. 1929, Ep.Timesteps 24, Episode Reward_naive: -889.00
# Ep. 1930, Ep.Timesteps 24, Episode Reward: -1076.96Ep. 1930, Ep.Timesteps 24, Episode Reward_naive: -971.00
# Ep. 1931, Ep.Timesteps 24, Episode Reward: -1329.96Ep. 1931, Ep.Timesteps 24, Episode Reward_naive: -1210.00
# Ep. 1932, Ep.Timesteps 24, Episode Reward: -1114.13Ep. 1932, Ep.Timesteps 24, Episode Reward_naive: -993.00
# Ep. 1933, Ep.Timesteps 24, Episode Reward: -998.35Ep. 1933, Ep.Timesteps 24, Episode Reward_naive: -905.00
# Ep. 1934, Ep.Timesteps 24, Episode Reward: -865.61Ep. 1934, Ep.Timesteps 24, Episode Reward_naive: -788.00
# Ep. 1935, Ep.Timesteps 24, Episode Reward: -1140.78Ep. 1935, Ep.Timesteps 24, Episode Reward_naive: -1031.00
# Ep. 1936, Ep.Timesteps 24, Episode Reward: -1116.66Ep. 1936, Ep.Timesteps 24, Episode Reward_naive: -995.00
# Ep. 1937, Ep.Timesteps 24, Episode Reward: -917.85Ep. 1937, Ep.Timesteps 24, Episode Reward_naive: -834.00
# Ep. 1938, Ep.Timesteps 24, Episode Reward: -1008.73Ep. 1938, Ep.Timesteps 24, Episode Reward_naive: -916.00
# Ep. 1939, Ep.Timesteps 24, Episode Reward: -1110.93Ep. 1939, Ep.Timesteps 24, Episode Reward_naive: -987.00
# Ep. 1940, Ep.Timesteps 24, Episode Reward: -863.51Ep. 1940, Ep.Timesteps 24, Episode Reward_naive: -781.00
# Ep. 1941, Ep.Timesteps 24, Episode Reward: -995.19Ep. 1941, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 1942, Ep.Timesteps 24, Episode Reward: -1307.35Ep. 1942, Ep.Timesteps 24, Episode Reward_naive: -1188.00
# Ep. 1943, Ep.Timesteps 24, Episode Reward: -1064.24Ep. 1943, Ep.Timesteps 24, Episode Reward_naive: -966.00
# Ep. 1944, Ep.Timesteps 24, Episode Reward: -1107.65Ep. 1944, Ep.Timesteps 24, Episode Reward_naive: -1006.00
# Ep. 1945, Ep.Timesteps 24, Episode Reward: -1148.22Ep. 1945, Ep.Timesteps 24, Episode Reward_naive: -1040.00
# Ep. 1946, Ep.Timesteps 24, Episode Reward: -917.79Ep. 1946, Ep.Timesteps 24, Episode Reward_naive: -833.00
# Ep. 1947, Ep.Timesteps 24, Episode Reward: -995.04Ep. 1947, Ep.Timesteps 24, Episode Reward_naive: -904.00
# Ep. 1948, Ep.Timesteps 24, Episode Reward: -1037.04Ep. 1948, Ep.Timesteps 24, Episode Reward_naive: -937.00
# Ep. 1949, Ep.Timesteps 24, Episode Reward: -1024.66Ep. 1949, Ep.Timesteps 24, Episode Reward_naive: -930.00
# Ep. 1950, Ep.Timesteps 24, Episode Reward: -901.28Ep. 1950, Ep.Timesteps 24, Episode Reward_naive: -820.00
# Ep. 1951, Ep.Timesteps 24, Episode Reward: -1047.48Ep. 1951, Ep.Timesteps 24, Episode Reward_naive: -950.00
# Ep. 1952, Ep.Timesteps 24, Episode Reward: -1085.17Ep. 1952, Ep.Timesteps 24, Episode Reward_naive: -988.00
# Ep. 1953, Ep.Timesteps 24, Episode Reward: -1166.69Ep. 1953, Ep.Timesteps 24, Episode Reward_naive: -1060.00
# Ep. 1954, Ep.Timesteps 24, Episode Reward: -1026.59Ep. 1954, Ep.Timesteps 24, Episode Reward_naive: -930.00
# Ep. 1955, Ep.Timesteps 24, Episode Reward: -1005.50Ep. 1955, Ep.Timesteps 24, Episode Reward_naive: -912.00
# Ep. 1956, Ep.Timesteps 24, Episode Reward: -1106.91Ep. 1956, Ep.Timesteps 24, Episode Reward_naive: -1005.00
# Ep. 1957, Ep.Timesteps 24, Episode Reward: -1079.71Ep. 1957, Ep.Timesteps 24, Episode Reward_naive: -978.00
# Ep. 1958, Ep.Timesteps 24, Episode Reward: -1047.52Ep. 1958, Ep.Timesteps 24, Episode Reward_naive: -951.00
# Ep. 1959, Ep.Timesteps 24, Episode Reward: -1191.16Ep. 1959, Ep.Timesteps 24, Episode Reward_naive: -1082.00
# Ep. 1960, Ep.Timesteps 24, Episode Reward: -830.91Ep. 1960, Ep.Timesteps 24, Episode Reward_naive: -755.00
# Ep. 1961, Ep.Timesteps 24, Episode Reward: -869.07Ep. 1961, Ep.Timesteps 24, Episode Reward_naive: -789.00
# Ep. 1962, Ep.Timesteps 24, Episode Reward: -975.87Ep. 1962, Ep.Timesteps 24, Episode Reward_naive: -887.00
# Ep. 1963, Ep.Timesteps 24, Episode Reward: -824.55Ep. 1963, Ep.Timesteps 24, Episode Reward_naive: -749.00
# Ep. 1964, Ep.Timesteps 24, Episode Reward: -1087.92Ep. 1964, Ep.Timesteps 24, Episode Reward_naive: -987.00
# Ep. 1965, Ep.Timesteps 24, Episode Reward: -914.92Ep. 1965, Ep.Timesteps 24, Episode Reward_naive: -831.00
# Ep. 1966, Ep.Timesteps 24, Episode Reward: -1064.32Ep. 1966, Ep.Timesteps 24, Episode Reward_naive: -942.00
# Ep. 1967, Ep.Timesteps 24, Episode Reward: -1005.07Ep. 1967, Ep.Timesteps 24, Episode Reward_naive: -913.00
# Ep. 1968, Ep.Timesteps 24, Episode Reward: -1015.94Ep. 1968, Ep.Timesteps 24, Episode Reward_naive: -898.00
# Ep. 1969, Ep.Timesteps 24, Episode Reward: -735.67Ep. 1969, Ep.Timesteps 24, Episode Reward_naive: -667.00
# Ep. 1970, Ep.Timesteps 24, Episode Reward: -965.82Ep. 1970, Ep.Timesteps 24, Episode Reward_naive: -875.00
# Ep. 1971, Ep.Timesteps 24, Episode Reward: -1219.35Ep. 1971, Ep.Timesteps 24, Episode Reward_naive: -1107.00
# Ep. 1972, Ep.Timesteps 24, Episode Reward: -1133.87Ep. 1972, Ep.Timesteps 24, Episode Reward_naive: -1029.00
# Ep. 1973, Ep.Timesteps 24, Episode Reward: -1192.05Ep. 1973, Ep.Timesteps 24, Episode Reward_naive: -1082.00
# Ep. 1974, Ep.Timesteps 24, Episode Reward: -906.31Ep. 1974, Ep.Timesteps 24, Episode Reward_naive: -822.00
# Ep. 1975, Ep.Timesteps 24, Episode Reward: -1059.30Ep. 1975, Ep.Timesteps 24, Episode Reward_naive: -957.00
# Ep. 1976, Ep.Timesteps 24, Episode Reward: -981.66Ep. 1976, Ep.Timesteps 24, Episode Reward_naive: -889.00
# Ep. 1977, Ep.Timesteps 24, Episode Reward: -1088.56Ep. 1977, Ep.Timesteps 24, Episode Reward_naive: -943.00
# Ep. 1978, Ep.Timesteps 24, Episode Reward: -1069.29Ep. 1978, Ep.Timesteps 24, Episode Reward_naive: -968.00
# Ep. 1979, Ep.Timesteps 24, Episode Reward: -884.70Ep. 1979, Ep.Timesteps 24, Episode Reward_naive: -802.00
# Ep. 1980, Ep.Timesteps 24, Episode Reward: -1129.97Ep. 1980, Ep.Timesteps 24, Episode Reward_naive: -1001.00
# Ep. 1981, Ep.Timesteps 24, Episode Reward: -835.19Ep. 1981, Ep.Timesteps 24, Episode Reward_naive: -757.00
# Ep. 1982, Ep.Timesteps 24, Episode Reward: -1307.82Ep. 1982, Ep.Timesteps 24, Episode Reward_naive: -1132.00
# Ep. 1983, Ep.Timesteps 24, Episode Reward: -995.25Ep. 1983, Ep.Timesteps 24, Episode Reward_naive: -899.00
# Ep. 1984, Ep.Timesteps 24, Episode Reward: -1112.17Ep. 1984, Ep.Timesteps 24, Episode Reward_naive: -1008.00
# Ep. 1985, Ep.Timesteps 24, Episode Reward: -1022.74Ep. 1985, Ep.Timesteps 24, Episode Reward_naive: -923.00
# Ep. 1986, Ep.Timesteps 24, Episode Reward: -981.26Ep. 1986, Ep.Timesteps 24, Episode Reward_naive: -892.00
# Ep. 1987, Ep.Timesteps 24, Episode Reward: -1240.77Ep. 1987, Ep.Timesteps 24, Episode Reward_naive: -1124.00
# Ep. 1988, Ep.Timesteps 24, Episode Reward: -1071.04Ep. 1988, Ep.Timesteps 24, Episode Reward_naive: -974.00
# Ep. 1989, Ep.Timesteps 24, Episode Reward: -1022.24Ep. 1989, Ep.Timesteps 24, Episode Reward_naive: -930.00
# Ep. 1990, Ep.Timesteps 24, Episode Reward: -1159.51Ep. 1990, Ep.Timesteps 24, Episode Reward_naive: -1052.00
# Ep. 1991, Ep.Timesteps 24, Episode Reward: -1135.70Ep. 1991, Ep.Timesteps 24, Episode Reward_naive: -1031.00
# Ep. 1992, Ep.Timesteps 24, Episode Reward: -992.88Ep. 1992, Ep.Timesteps 24, Episode Reward_naive: -903.00
# Ep. 1993, Ep.Timesteps 24, Episode Reward: -997.38Ep. 1993, Ep.Timesteps 24, Episode Reward_naive: -908.00
# Ep. 1994, Ep.Timesteps 24, Episode Reward: -1081.05Ep. 1994, Ep.Timesteps 24, Episode Reward_naive: -982.00
# Ep. 1995, Ep.Timesteps 24, Episode Reward: -1004.41Ep. 1995, Ep.Timesteps 24, Episode Reward_naive: -911.00
# Ep. 1996, Ep.Timesteps 24, Episode Reward: -1024.70Ep. 1996, Ep.Timesteps 24, Episode Reward_naive: -931.00
# Ep. 1997, Ep.Timesteps 24, Episode Reward: -1018.29Ep. 1997, Ep.Timesteps 24, Episode Reward_naive: -926.00
# Ep. 1998, Ep.Timesteps 24, Episode Reward: -742.54Ep. 1998, Ep.Timesteps 24, Episode Reward_naive: -673.00
# Ep. 1999, Ep.Timesteps 24, Episode Reward: -1125.91Ep. 1999, Ep.Timesteps 24, Episode Reward_naive: -1024.00
# Ep. 2000, Ep.Timesteps 24, Episode Reward: -1074.15Ep. 2000, Ep.Timesteps 24, Episode Reward_naive: -976.00
# Average reward over 50 episodes:  -977.9096533865298
# -958.3095376172906 -955.2075

# %%
a = -(np.array(ep_reward_list) - np.array(ep_reward_list_naive)) / ep_reward_list_naive
plt.plot(a)
plt.xlabel('episode number')
plt.ylabel('performance difference')
plt.show()
plt.savefig('final result.png')

# %%
plt.plot(ep_reward_list,color = 'r')
plt.plot(ep_reward_list_naive, color = 'b')
plt.xlabel('episode number')
plt.ylabel('performance score')
plt.show()
plt.savefig('final result 1.png')

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)
